# %% [markdown]
# ### 1. Model Design

# %%
import numpy as np

# %%
# activation function and their derivatives
def relu(Z):
    return np.maximum(0, Z)

def relu_derivative(Z):
    return Z > 0

def sigmoid(Z):
    return 1 / (1 + np.exp(-Z))

def sigmoid_derivative(Z):
    s = sigmoid(Z)
    return s * (1 - s)

def softmax(Z):
    e_Z = np.exp(Z - np.max(Z, axis=0, keepdims=True))
    return e_Z / e_Z.sum(axis=0, keepdims=True)

activation_functions = {
    "relu": {"function": relu, "derivative": relu_derivative},
    "sigmoid": {"function": sigmoid, "derivative": sigmoid_derivative},
    "softmax": {"function": softmax, "derivative": None}  # Derivative not directly used
}

# %%
def initialize_parameters(layer_sizes):
    np.random.seed(1)
    parameters = {}
    L = len(layer_sizes)
    
    for l in range(1, L):
        parameters[f'W{l}'] = np.random.randn(layer_sizes[l], layer_sizes[l-1]) * 0.01
        parameters[f'b{l}'] = np.zeros((layer_sizes[l], 1))
    
    return parameters

# %%
def forward_propagation(X, parameters, activations):
    caches = []
    A = X
    
    L = len(parameters) // 2  
    for l in range(1, L + 1):
        W = parameters[f'W{l}']
        b = parameters[f'b{l}']
        A_prev = A
        Z = np.dot(W, A_prev) + b
        A = activation_functions[activations[l-1]]['function'](Z)
        caches.append((A_prev, W, b, Z)) 
    
    return A, caches

# %%
def compute_cost(A, Y, parameters, lambd):
    m = Y.shape[1]
    # Calculate the log probabilities
    log_probs = -np.log(A + 1e-8) * Y  # Element-wise multiplication
    cross_entropy_cost = np.sum(log_probs) / m

    # Add L2 regularization cost
    L2_cost = 0
    L = len(parameters) // 3
    for l in range(1, L + 1):
        W = parameters[f'W{l}']
        L2_cost += (lambd / (2 * m)) * np.sum(np.square(W))

    total_cost = cross_entropy_cost + L2_cost
    return total_cost

# %%
def backward_propagation(Y, A_final, caches, parameters, activations, lambd):
    gradients = {}
    L = len(caches)  # The number of layers (except the output layer)
    m = A_final.shape[1]

    # Initialize backpropagation
    # For the last layer, the derivative of the cost with respect to A_final is simply (A_final - Y)
    dZ = A_final - Y

    # Calculate the gradient of the output layer
    A_prev, W, b, Z = caches[1]
    dW = np.dot(dZ, A_prev.T) / m + (lambd * W) / m
    db = np.sum(dZ, axis=1, keepdims=True) / m
    gradients[f'dW{2}'] = dW
    gradients[f'db{2}'] = db
    dA_prev = np.dot(W.T, dZ)  # Prepare for calculating the gradient of the hidden layer

    # Calculate the gradient of the hidden layer
    A_prev, W, b, Z = caches[0]
    activation = activations[0]
    derivative_function = activation_functions[activation]['derivative']
    dZ = dA_prev * derivative_function(Z)  # Element-wise multiplication of dA and the derivative of Z
    dW = np.dot(dZ, A_prev.T) / m + (lambd * W) / m
    db = np.sum(dZ, axis=1, keepdims=True) / m
    gradients[f'dW{1}'] = dW
    gradients[f'db{1}'] = db

    return gradients

# %%
def update_parameters(parameters, gradients, learning_rate):
    L = len(parameters) // 2
    for l in range(1, L + 1):
        parameters[f'W{l}'] -= learning_rate * gradients[f'dW{l}']
        parameters[f'b{l}'] -= learning_rate * gradients[f'db{l}']
    return parameters

# %% [markdown]
# ### 2. Model Training

# %%
import numpy as np
import gzip

def load_images(file_path):
    with gzip.open(file_path, 'rb') as f:
        magic = int.from_bytes(f.read(4), 'big')
        num_images = int.from_bytes(f.read(4), 'big')
        rows = int.from_bytes(f.read(4), 'big')
        cols = int.from_bytes(f.read(4), 'big')
        data = np.frombuffer(f.read(), dtype=np.uint8).reshape(num_images, rows * cols)
        if data.size == 0:
            raise ValueError("No data loaded; check file path and file integrity.")
        return data / 255.0  # Normalize the data

def load_labels(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(8)  # Read and skip the header bytes
        labels = np.frombuffer(f.read(), dtype=np.uint8)
        if labels.size == 0:
            raise ValueError("No label data loaded; check file path and file integrity.")
        return labels

# Paths to data files
train_images_path = 'train-images-idx3-ubyte.gz'
train_labels_path = 'train-labels-idx1-ubyte.gz'
test_images_path = 't10k-images-idx3-ubyte.gz'
test_labels_path = 't10k-labels-idx1-ubyte.gz'

# %%
X_train = load_images(train_images_path)
X_test = load_images(test_images_path)
print("Initial X_train shape:", X_train.shape)
print("Initial X_test shape:", X_test.shape)
# Out:
# Initial X_train shape: (60000, 784)
# Initial X_test shape: (10000, 784)

# %%
def one_hot_encode(labels, num_classes=10):
    # Create an array of zeros with length num_classes for each label
    return np.eye(num_classes)[labels]

# %%
y_train = load_labels(train_labels_path)
y_test = load_labels(test_labels_path)

print("y_train raw shape:", y_train.shape)
print("y_test raw shape:", y_test.shape)
# Out:
# y_train raw shape: (60000,)
# y_test raw shape: (10000,)

# %%
# Ensure proper dimensions
X_train = X_train.T
X_test = X_test.T
y_train_encoded = one_hot_encode(y_train).T
y_test_encoded = one_hot_encode(y_test).T

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train_encoded.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test_encoded.shape)
# Out:
# X_train shape: (784, 60000)
# y_train shape: (10, 60000)
# X_test shape: (784, 10000)
# y_test shape: (10, 10000)

# %%
def compute_accuracy(output, labels):
    predictions = np.argmax(output, axis=0)
    labels = np.argmax(labels, axis=0)
    return np.mean(predictions == labels)

# %%
def train_and_evaluate_model(X_train, y_train, X_val, y_val, layer_sizes, activations, learning_rate, num_iterations, lambd):
    parameters = initialize_parameters(layer_sizes)
    train_costs = []
    val_costs = []
    val_accuracies = []
    best_accuracy = 0
    best_params = None
    
    for i in range(num_iterations):
        # Train on training data
        A_train, caches_train = forward_propagation(X_train, parameters, activations)
        train_cost = compute_cost(A_train, y_train, parameters, lambd)
        train_costs.append(train_cost)
        gradients = backward_propagation(y_train, A_train, caches_train, parameters, activations, lambd)
        parameters = update_parameters(parameters, gradients, learning_rate)
        
        # Evaluate on validation data
        if i % 10 == 0 or i == num_iterations - 1:  # Optionally check more frequently
            A_val, caches_val = forward_propagation(X_val, parameters, activations)
            val_cost = compute_cost(A_val, y_val, parameters, lambd)
            val_costs.append(val_cost)
            accuracy = compute_accuracy(A_val, y_val)
            val_accuracies.append(accuracy)
            
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_params = parameters.copy()
                
            print(f"Iteration {i}: Train Cost = {train_cost:.4f}, Val Cost = {val_cost:.4f}, Val Accuracy = {accuracy:.4f}")
    
    return best_params, train_costs, val_costs, val_accuracies

# %%
import matplotlib.pyplot as plt

def plot_metrics(train_costs, val_costs, val_accuracies):
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_costs, label='Training Loss')
    plt.plot(np.arange(len(val_costs)) * 10, val_costs, label='Validation Loss')  # Assuming validation every 10 iterations
    plt.title('Training and Validation Loss')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(np.arange(len(val_accuracies)) * 10, val_accuracies, label='Validation Accuracy')
    plt.title('Validation Accuracy')
    plt.xlabel('Iteration')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
# Test training
layer_sizes = [784, 128, 10]  # For an input layer of 28*28 pixels, one hidden layer, and 10 output classes
activations = ['relu', 'softmax']
best_params, train_costs, val_costs, val_accuracies = train_and_evaluate_model(
    X_train, y_train_encoded, X_test, y_test_encoded, layer_sizes, activations,
    learning_rate=0.01, num_iterations=200, lambd=0.1
)
plot_metrics(train_costs, val_costs, val_accuracies)
# Out:
# Iteration 0: Train Cost = 2.3005, Val Cost = 2.3002, Val Accuracy = 0.1088
# Iteration 10: Train Cost = 2.2969, Val Cost = 2.2966, Val Accuracy = 0.1438
# Iteration 20: Train Cost = 2.2931, Val Cost = 2.2927, Val Accuracy = 0.1729
# Iteration 30: Train Cost = 2.2889, Val Cost = 2.2885, Val Accuracy = 0.2272
# Iteration 40: Train Cost = 2.2843, Val Cost = 2.2839, Val Accuracy = 0.2583
# Iteration 50: Train Cost = 2.2792, Val Cost = 2.2787, Val Accuracy = 0.2617
# Iteration 60: Train Cost = 2.2734, Val Cost = 2.2729, Val Accuracy = 0.2524
# Iteration 70: Train Cost = 2.2668, Val Cost = 2.2662, Val Accuracy = 0.2405
# Iteration 80: Train Cost = 2.2594, Val Cost = 2.2587, Val Accuracy = 0.2282
# Iteration 90: Train Cost = 2.2510, Val Cost = 2.2502, Val Accuracy = 0.2173
# Iteration 100: Train Cost = 2.2415, Val Cost = 2.2406, Val Accuracy = 0.2089
# Iteration 110: Train Cost = 2.2309, Val Cost = 2.2299, Val Accuracy = 0.2037
# Iteration 120: Train Cost = 2.2190, Val Cost = 2.2179, Val Accuracy = 0.2021
# Iteration 130: Train Cost = 2.2060, Val Cost = 2.2048, Val Accuracy = 0.2036
# Iteration 140: Train Cost = 2.1916, Val Cost = 2.1903, Val Accuracy = 0.2074
# Iteration 150: Train Cost = 2.1759, Val Cost = 2.1745, Val Accuracy = 0.2152
# Iteration 160: Train Cost = 2.1588, Val Cost = 2.1573, Val Accuracy = 0.2275
# Iteration 170: Train Cost = 2.1402, Val Cost = 2.1387, Val Accuracy = 0.2408
# Iteration 180: Train Cost = 2.1202, Val Cost = 2.1186, Val Accuracy = 0.2684
# Iteration 190: Train Cost = 2.0987, Val Cost = 2.0970, Val Accuracy = 0.3110
# Iteration 199: Train Cost = 2.0780, Val Cost = 2.0762, Val Accuracy = 0.3448

# %% [markdown]
# ### 3. Parameter Tuning

# %%
learning_rates = [0.001, 0.01, 0.1]
hidden_layer_sizes = [50, 100, 150]
regularization_strengths = [0.001, 0.01, 0.1]

# %%
import numpy as np

def grid_search(X_train, y_train, X_test, y_test):
    results = []
    best_accuracy = 0
    best_params = None
    
    for lr in learning_rates:
        for size in hidden_layer_sizes:
            for lambd in regularization_strengths:
                print(f"Testing with learning rate: {lr}, hidden layer size: {size}, lambda: {lambd}")
                
                layer_sizes = [784, size, 10]  # Adjust the hidden layer size
                activations = ['relu', 'softmax']
                
                params, costs, _, _ = train_and_evaluate_model(
                    X_train, y_train, X_test, y_test, layer_sizes, activations,
                    learning_rate=lr, num_iterations=500, lambd=lambd
                )
                
                final_accuracy = compute_accuracy(forward_propagation(X_test, params, activations)[0], y_test)
                results.append((lr, size, lambd, final_accuracy))
                
                if final_accuracy > best_accuracy:
                    best_accuracy = final_accuracy
                    best_params = {'lr': lr, 'size': size, 'lambda': lambd, 'accuracy': final_accuracy}

                print(f"Accuracy: {final_accuracy}")
    
    return best_params, results

# %%
best_params, tuning_results = grid_search(X_train, y_train_encoded, X_test, y_test_encoded)
print("Best Parameters:", best_params)
# Out:
# Testing with learning rate: 0.001, hidden layer size: 50, lambda: 0.001
# Iteration 0: Train Cost = 2.3027, Val Cost = 2.3026, Val Accuracy = 0.1432
# Iteration 10: Train Cost = 2.3025, Val Cost = 2.3025, Val Accuracy = 0.1451
# Iteration 20: Train Cost = 2.3024, Val Cost = 2.3023, Val Accuracy = 0.1478
# Iteration 30: Train Cost = 2.3022, Val Cost = 2.3022, Val Accuracy = 0.1504
# Iteration 40: Train Cost = 2.3021, Val Cost = 2.3020, Val Accuracy = 0.1521
# Iteration 50: Train Cost = 2.3019, Val Cost = 2.3018, Val Accuracy = 0.1541
# Iteration 60: Train Cost = 2.3018, Val Cost = 2.3017, Val Accuracy = 0.1565
# Iteration 70: Train Cost = 2.3016, Val Cost = 2.3015, Val Accuracy = 0.1593
# Iteration 80: Train Cost = 2.3014, Val Cost = 2.3014, Val Accuracy = 0.1607
# Iteration 90: Train Cost = 2.3013, Val Cost = 2.3012, Val Accuracy = 0.1628
# Iteration 100: Train Cost = 2.3011, Val Cost = 2.3011, Val Accuracy = 0.1647
# Iteration 110: Train Cost = 2.3010, Val Cost = 2.3009, Val Accuracy = 0.1665
# Iteration 120: Train Cost = 2.3008, Val Cost = 2.3008, Val Accuracy = 0.1684
# Iteration 130: Train Cost = 2.3007, Val Cost = 2.3006, Val Accuracy = 0.1701
# Iteration 140: Train Cost = 2.3005, Val Cost = 2.3005, Val Accuracy = 0.1712
# Iteration 150: Train Cost = 2.3004, Val Cost = 2.3003, Val Accuracy = 0.1727
# Iteration 160: Train Cost = 2.3002, Val Cost = 2.3001, Val Accuracy = 0.1734
# Iteration 170: Train Cost = 2.3000, Val Cost = 2.3000, Val Accuracy = 0.1753
# Iteration 180: Train Cost = 2.2999, Val Cost = 2.2998, Val Accuracy = 0.1774
# Iteration 190: Train Cost = 2.2997, Val Cost = 2.2997, Val Accuracy = 0.1784
# Iteration 200: Train Cost = 2.2996, Val Cost = 2.2995, Val Accuracy = 0.1795
# Iteration 210: Train Cost = 2.2994, Val Cost = 2.2994, Val Accuracy = 0.1808
# Iteration 220: Train Cost = 2.2993, Val Cost = 2.2992, Val Accuracy = 0.1818
# Iteration 230: Train Cost = 2.2991, Val Cost = 2.2990, Val Accuracy = 0.1829
# Iteration 240: Train Cost = 2.2989, Val Cost = 2.2989, Val Accuracy = 0.1856
# Iteration 250: Train Cost = 2.2988, Val Cost = 2.2987, Val Accuracy = 0.1883
# Iteration 260: Train Cost = 2.2986, Val Cost = 2.2985, Val Accuracy = 0.1894
# Iteration 270: Train Cost = 2.2984, Val Cost = 2.2984, Val Accuracy = 0.1909
# Iteration 280: Train Cost = 2.2983, Val Cost = 2.2982, Val Accuracy = 0.1918
# Iteration 290: Train Cost = 2.2981, Val Cost = 2.2980, Val Accuracy = 0.1939
# Iteration 300: Train Cost = 2.2979, Val Cost = 2.2979, Val Accuracy = 0.1959
# Iteration 310: Train Cost = 2.2977, Val Cost = 2.2977, Val Accuracy = 0.1978
# Iteration 320: Train Cost = 2.2976, Val Cost = 2.2975, Val Accuracy = 0.1987
# Iteration 330: Train Cost = 2.2974, Val Cost = 2.2973, Val Accuracy = 0.2012
# Iteration 340: Train Cost = 2.2972, Val Cost = 2.2972, Val Accuracy = 0.2035
# Iteration 350: Train Cost = 2.2970, Val Cost = 2.2970, Val Accuracy = 0.2046
# Iteration 360: Train Cost = 2.2969, Val Cost = 2.2968, Val Accuracy = 0.2062
# Iteration 370: Train Cost = 2.2967, Val Cost = 2.2966, Val Accuracy = 0.2075
# Iteration 380: Train Cost = 2.2965, Val Cost = 2.2964, Val Accuracy = 0.2091
# Iteration 390: Train Cost = 2.2963, Val Cost = 2.2963, Val Accuracy = 0.2102
# Iteration 400: Train Cost = 2.2961, Val Cost = 2.2961, Val Accuracy = 0.2125
# Iteration 410: Train Cost = 2.2959, Val Cost = 2.2959, Val Accuracy = 0.2131
# Iteration 420: Train Cost = 2.2957, Val Cost = 2.2957, Val Accuracy = 0.2135
# Iteration 430: Train Cost = 2.2955, Val Cost = 2.2955, Val Accuracy = 0.2159
# Iteration 440: Train Cost = 2.2953, Val Cost = 2.2953, Val Accuracy = 0.2162
# Iteration 450: Train Cost = 2.2951, Val Cost = 2.2951, Val Accuracy = 0.2184
# Iteration 460: Train Cost = 2.2949, Val Cost = 2.2949, Val Accuracy = 0.2196
# Iteration 470: Train Cost = 2.2947, Val Cost = 2.2947, Val Accuracy = 0.2216
# Iteration 480: Train Cost = 2.2945, Val Cost = 2.2945, Val Accuracy = 0.2226
# Iteration 490: Train Cost = 2.2943, Val Cost = 2.2942, Val Accuracy = 0.2243
# Iteration 499: Train Cost = 2.2941, Val Cost = 2.2941, Val Accuracy = 0.2261
# Accuracy: 0.2261
# Testing with learning rate: 0.001, hidden layer size: 50, lambda: 0.01
# Iteration 0: Train Cost = 2.3027, Val Cost = 2.3026, Val Accuracy = 0.1432
# Iteration 10: Train Cost = 2.3025, Val Cost = 2.3025, Val Accuracy = 0.1451
# Iteration 20: Train Cost = 2.3024, Val Cost = 2.3023, Val Accuracy = 0.1478
# Iteration 30: Train Cost = 2.3022, Val Cost = 2.3022, Val Accuracy = 0.1504
# Iteration 40: Train Cost = 2.3021, Val Cost = 2.3020, Val Accuracy = 0.1521
# Iteration 50: Train Cost = 2.3019, Val Cost = 2.3018, Val Accuracy = 0.1541
# Iteration 60: Train Cost = 2.3018, Val Cost = 2.3017, Val Accuracy = 0.1565
# Iteration 70: Train Cost = 2.3016, Val Cost = 2.3015, Val Accuracy = 0.1593
# Iteration 80: Train Cost = 2.3014, Val Cost = 2.3014, Val Accuracy = 0.1607
# Iteration 90: Train Cost = 2.3013, Val Cost = 2.3012, Val Accuracy = 0.1628
# Iteration 100: Train Cost = 2.3011, Val Cost = 2.3011, Val Accuracy = 0.1647
# Iteration 110: Train Cost = 2.3010, Val Cost = 2.3009, Val Accuracy = 0.1665
# Iteration 120: Train Cost = 2.3008, Val Cost = 2.3008, Val Accuracy = 0.1684
# Iteration 130: Train Cost = 2.3007, Val Cost = 2.3006, Val Accuracy = 0.1701
# Iteration 140: Train Cost = 2.3005, Val Cost = 2.3005, Val Accuracy = 0.1712
# Iteration 150: Train Cost = 2.3004, Val Cost = 2.3003, Val Accuracy = 0.1727
# Iteration 160: Train Cost = 2.3002, Val Cost = 2.3002, Val Accuracy = 0.1734
# Iteration 170: Train Cost = 2.3000, Val Cost = 2.3000, Val Accuracy = 0.1753
# Iteration 180: Train Cost = 2.2999, Val Cost = 2.2998, Val Accuracy = 0.1774
# Iteration 190: Train Cost = 2.2997, Val Cost = 2.2997, Val Accuracy = 0.1784
# Iteration 200: Train Cost = 2.2996, Val Cost = 2.2995, Val Accuracy = 0.1795
# Iteration 210: Train Cost = 2.2994, Val Cost = 2.2994, Val Accuracy = 0.1808
# Iteration 220: Train Cost = 2.2993, Val Cost = 2.2992, Val Accuracy = 0.1818
# Iteration 230: Train Cost = 2.2991, Val Cost = 2.2990, Val Accuracy = 0.1829
# Iteration 240: Train Cost = 2.2989, Val Cost = 2.2989, Val Accuracy = 0.1856
# Iteration 250: Train Cost = 2.2988, Val Cost = 2.2987, Val Accuracy = 0.1883
# Iteration 260: Train Cost = 2.2986, Val Cost = 2.2985, Val Accuracy = 0.1894
# Iteration 270: Train Cost = 2.2984, Val Cost = 2.2984, Val Accuracy = 0.1909
# Iteration 280: Train Cost = 2.2983, Val Cost = 2.2982, Val Accuracy = 0.1918
# Iteration 290: Train Cost = 2.2981, Val Cost = 2.2980, Val Accuracy = 0.1939
# Iteration 300: Train Cost = 2.2979, Val Cost = 2.2979, Val Accuracy = 0.1959
# Iteration 310: Train Cost = 2.2978, Val Cost = 2.2977, Val Accuracy = 0.1978
# Iteration 320: Train Cost = 2.2976, Val Cost = 2.2975, Val Accuracy = 0.1987
# Iteration 330: Train Cost = 2.2974, Val Cost = 2.2973, Val Accuracy = 0.2012
# Iteration 340: Train Cost = 2.2972, Val Cost = 2.2972, Val Accuracy = 0.2035
# Iteration 350: Train Cost = 2.2970, Val Cost = 2.2970, Val Accuracy = 0.2046
# Iteration 360: Train Cost = 2.2969, Val Cost = 2.2968, Val Accuracy = 0.2062
# Iteration 370: Train Cost = 2.2967, Val Cost = 2.2966, Val Accuracy = 0.2075
# Iteration 380: Train Cost = 2.2965, Val Cost = 2.2964, Val Accuracy = 0.2091
# Iteration 390: Train Cost = 2.2963, Val Cost = 2.2963, Val Accuracy = 0.2102
# Iteration 400: Train Cost = 2.2961, Val Cost = 2.2961, Val Accuracy = 0.2125
# Iteration 410: Train Cost = 2.2959, Val Cost = 2.2959, Val Accuracy = 0.2131
# Iteration 420: Train Cost = 2.2957, Val Cost = 2.2957, Val Accuracy = 0.2135
# Iteration 430: Train Cost = 2.2955, Val Cost = 2.2955, Val Accuracy = 0.2159
# Iteration 440: Train Cost = 2.2953, Val Cost = 2.2953, Val Accuracy = 0.2162
# Iteration 450: Train Cost = 2.2951, Val Cost = 2.2951, Val Accuracy = 0.2184
# Iteration 460: Train Cost = 2.2949, Val Cost = 2.2949, Val Accuracy = 0.2196
# Iteration 470: Train Cost = 2.2947, Val Cost = 2.2947, Val Accuracy = 0.2216
# Iteration 480: Train Cost = 2.2945, Val Cost = 2.2945, Val Accuracy = 0.2226
# Iteration 490: Train Cost = 2.2943, Val Cost = 2.2943, Val Accuracy = 0.2243
# Iteration 499: Train Cost = 2.2941, Val Cost = 2.2941, Val Accuracy = 0.2261
# Accuracy: 0.2261
# Testing with learning rate: 0.001, hidden layer size: 50, lambda: 0.1
# Iteration 0: Train Cost = 2.3027, Val Cost = 2.3026, Val Accuracy = 0.1432
# Iteration 10: Train Cost = 2.3025, Val Cost = 2.3025, Val Accuracy = 0.1451
# Iteration 20: Train Cost = 2.3024, Val Cost = 2.3023, Val Accuracy = 0.1478
# Iteration 30: Train Cost = 2.3022, Val Cost = 2.3022, Val Accuracy = 0.1504
# Iteration 40: Train Cost = 2.3021, Val Cost = 2.3020, Val Accuracy = 0.1521
# Iteration 50: Train Cost = 2.3019, Val Cost = 2.3019, Val Accuracy = 0.1541
# Iteration 60: Train Cost = 2.3018, Val Cost = 2.3017, Val Accuracy = 0.1565
# Iteration 70: Train Cost = 2.3016, Val Cost = 2.3016, Val Accuracy = 0.1593
# Iteration 80: Train Cost = 2.3014, Val Cost = 2.3014, Val Accuracy = 0.1607
# Iteration 90: Train Cost = 2.3013, Val Cost = 2.3013, Val Accuracy = 0.1628
# Iteration 100: Train Cost = 2.3011, Val Cost = 2.3011, Val Accuracy = 0.1647
# Iteration 110: Train Cost = 2.3010, Val Cost = 2.3009, Val Accuracy = 0.1665
# Iteration 120: Train Cost = 2.3008, Val Cost = 2.3008, Val Accuracy = 0.1684
# Iteration 130: Train Cost = 2.3007, Val Cost = 2.3006, Val Accuracy = 0.1701
# Iteration 140: Train Cost = 2.3005, Val Cost = 2.3005, Val Accuracy = 0.1712
# Iteration 150: Train Cost = 2.3004, Val Cost = 2.3003, Val Accuracy = 0.1727
# Iteration 160: Train Cost = 2.3002, Val Cost = 2.3002, Val Accuracy = 0.1734
# Iteration 170: Train Cost = 2.3001, Val Cost = 2.3000, Val Accuracy = 0.1753
# Iteration 180: Train Cost = 2.2999, Val Cost = 2.2999, Val Accuracy = 0.1774
# Iteration 190: Train Cost = 2.2997, Val Cost = 2.2997, Val Accuracy = 0.1784
# Iteration 200: Train Cost = 2.2996, Val Cost = 2.2995, Val Accuracy = 0.1795
# Iteration 210: Train Cost = 2.2994, Val Cost = 2.2994, Val Accuracy = 0.1808
# Iteration 220: Train Cost = 2.2993, Val Cost = 2.2992, Val Accuracy = 0.1818
# Iteration 230: Train Cost = 2.2991, Val Cost = 2.2991, Val Accuracy = 0.1829
# Iteration 240: Train Cost = 2.2989, Val Cost = 2.2989, Val Accuracy = 0.1856
# Iteration 250: Train Cost = 2.2988, Val Cost = 2.2987, Val Accuracy = 0.1883
# Iteration 260: Train Cost = 2.2986, Val Cost = 2.2986, Val Accuracy = 0.1894
# Iteration 270: Train Cost = 2.2984, Val Cost = 2.2984, Val Accuracy = 0.1909
# Iteration 280: Train Cost = 2.2983, Val Cost = 2.2982, Val Accuracy = 0.1918
# Iteration 290: Train Cost = 2.2981, Val Cost = 2.2981, Val Accuracy = 0.1939
# Iteration 300: Train Cost = 2.2979, Val Cost = 2.2979, Val Accuracy = 0.1959
# Iteration 310: Train Cost = 2.2978, Val Cost = 2.2977, Val Accuracy = 0.1978
# Iteration 320: Train Cost = 2.2976, Val Cost = 2.2975, Val Accuracy = 0.1987
# Iteration 330: Train Cost = 2.2974, Val Cost = 2.2974, Val Accuracy = 0.2012
# Iteration 340: Train Cost = 2.2972, Val Cost = 2.2972, Val Accuracy = 0.2035
# Iteration 350: Train Cost = 2.2970, Val Cost = 2.2970, Val Accuracy = 0.2046
# Iteration 360: Train Cost = 2.2969, Val Cost = 2.2968, Val Accuracy = 0.2062
# Iteration 370: Train Cost = 2.2967, Val Cost = 2.2966, Val Accuracy = 0.2075
# Iteration 380: Train Cost = 2.2965, Val Cost = 2.2965, Val Accuracy = 0.2091
# Iteration 390: Train Cost = 2.2963, Val Cost = 2.2963, Val Accuracy = 0.2102
# Iteration 400: Train Cost = 2.2961, Val Cost = 2.2961, Val Accuracy = 0.2125
# Iteration 410: Train Cost = 2.2959, Val Cost = 2.2959, Val Accuracy = 0.2131
# Iteration 420: Train Cost = 2.2957, Val Cost = 2.2957, Val Accuracy = 0.2135
# Iteration 430: Train Cost = 2.2955, Val Cost = 2.2955, Val Accuracy = 0.2159
# Iteration 440: Train Cost = 2.2953, Val Cost = 2.2953, Val Accuracy = 0.2162
# Iteration 450: Train Cost = 2.2951, Val Cost = 2.2951, Val Accuracy = 0.2184
# Iteration 460: Train Cost = 2.2949, Val Cost = 2.2949, Val Accuracy = 0.2196
# Iteration 470: Train Cost = 2.2947, Val Cost = 2.2947, Val Accuracy = 0.2216
# Iteration 480: Train Cost = 2.2945, Val Cost = 2.2945, Val Accuracy = 0.2226
# Iteration 490: Train Cost = 2.2943, Val Cost = 2.2943, Val Accuracy = 0.2243
# Iteration 499: Train Cost = 2.2941, Val Cost = 2.2941, Val Accuracy = 0.2261
# Accuracy: 0.2261
# Testing with learning rate: 0.001, hidden layer size: 100, lambda: 0.001
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.3014, Val Accuracy = 0.0979
# Iteration 10: Train Cost = 2.3011, Val Cost = 2.3012, Val Accuracy = 0.0982
# Iteration 20: Train Cost = 2.3009, Val Cost = 2.3009, Val Accuracy = 0.0986
# Iteration 30: Train Cost = 2.3006, Val Cost = 2.3006, Val Accuracy = 0.0990
# Iteration 40: Train Cost = 2.3003, Val Cost = 2.3004, Val Accuracy = 0.0998
# Iteration 50: Train Cost = 2.3001, Val Cost = 2.3001, Val Accuracy = 0.1003
# Iteration 60: Train Cost = 2.2998, Val Cost = 2.2998, Val Accuracy = 0.1014
# Iteration 70: Train Cost = 2.2995, Val Cost = 2.2996, Val Accuracy = 0.1024
# Iteration 80: Train Cost = 2.2993, Val Cost = 2.2993, Val Accuracy = 0.1032
# Iteration 90: Train Cost = 2.2990, Val Cost = 2.2990, Val Accuracy = 0.1048
# Iteration 100: Train Cost = 2.2987, Val Cost = 2.2988, Val Accuracy = 0.1059
# Iteration 110: Train Cost = 2.2984, Val Cost = 2.2985, Val Accuracy = 0.1080
# Iteration 120: Train Cost = 2.2982, Val Cost = 2.2982, Val Accuracy = 0.1098
# Iteration 130: Train Cost = 2.2979, Val Cost = 2.2979, Val Accuracy = 0.1116
# Iteration 140: Train Cost = 2.2976, Val Cost = 2.2977, Val Accuracy = 0.1140
# Iteration 150: Train Cost = 2.2973, Val Cost = 2.2974, Val Accuracy = 0.1169
# Iteration 160: Train Cost = 2.2971, Val Cost = 2.2971, Val Accuracy = 0.1209
# Iteration 170: Train Cost = 2.2968, Val Cost = 2.2968, Val Accuracy = 0.1245
# Iteration 180: Train Cost = 2.2965, Val Cost = 2.2965, Val Accuracy = 0.1281
# Iteration 190: Train Cost = 2.2962, Val Cost = 2.2962, Val Accuracy = 0.1313
# Iteration 200: Train Cost = 2.2959, Val Cost = 2.2960, Val Accuracy = 0.1357
# Iteration 210: Train Cost = 2.2956, Val Cost = 2.2957, Val Accuracy = 0.1400
# Iteration 220: Train Cost = 2.2953, Val Cost = 2.2954, Val Accuracy = 0.1447
# Iteration 230: Train Cost = 2.2950, Val Cost = 2.2951, Val Accuracy = 0.1499
# Iteration 240: Train Cost = 2.2947, Val Cost = 2.2948, Val Accuracy = 0.1555
# Iteration 250: Train Cost = 2.2944, Val Cost = 2.2945, Val Accuracy = 0.1606
# Iteration 260: Train Cost = 2.2941, Val Cost = 2.2942, Val Accuracy = 0.1660
# Iteration 270: Train Cost = 2.2938, Val Cost = 2.2939, Val Accuracy = 0.1717
# Iteration 280: Train Cost = 2.2935, Val Cost = 2.2936, Val Accuracy = 0.1773
# Iteration 290: Train Cost = 2.2932, Val Cost = 2.2932, Val Accuracy = 0.1842
# Iteration 300: Train Cost = 2.2929, Val Cost = 2.2929, Val Accuracy = 0.1894
# Iteration 310: Train Cost = 2.2925, Val Cost = 2.2926, Val Accuracy = 0.1945
# Iteration 320: Train Cost = 2.2922, Val Cost = 2.2923, Val Accuracy = 0.2003
# Iteration 330: Train Cost = 2.2919, Val Cost = 2.2920, Val Accuracy = 0.2059
# Iteration 340: Train Cost = 2.2916, Val Cost = 2.2916, Val Accuracy = 0.2123
# Iteration 350: Train Cost = 2.2912, Val Cost = 2.2913, Val Accuracy = 0.2173
# Iteration 360: Train Cost = 2.2909, Val Cost = 2.2910, Val Accuracy = 0.2239
# Iteration 370: Train Cost = 2.2905, Val Cost = 2.2906, Val Accuracy = 0.2286
# Iteration 380: Train Cost = 2.2902, Val Cost = 2.2903, Val Accuracy = 0.2345
# Iteration 390: Train Cost = 2.2899, Val Cost = 2.2899, Val Accuracy = 0.2398
# Iteration 400: Train Cost = 2.2895, Val Cost = 2.2896, Val Accuracy = 0.2449
# Iteration 410: Train Cost = 2.2891, Val Cost = 2.2892, Val Accuracy = 0.2493
# Iteration 420: Train Cost = 2.2888, Val Cost = 2.2889, Val Accuracy = 0.2545
# Iteration 430: Train Cost = 2.2884, Val Cost = 2.2885, Val Accuracy = 0.2583
# Iteration 440: Train Cost = 2.2881, Val Cost = 2.2881, Val Accuracy = 0.2633
# Iteration 450: Train Cost = 2.2877, Val Cost = 2.2878, Val Accuracy = 0.2690
# Iteration 460: Train Cost = 2.2873, Val Cost = 2.2874, Val Accuracy = 0.2755
# Iteration 470: Train Cost = 2.2869, Val Cost = 2.2870, Val Accuracy = 0.2794
# Iteration 480: Train Cost = 2.2865, Val Cost = 2.2866, Val Accuracy = 0.2829
# Iteration 490: Train Cost = 2.2861, Val Cost = 2.2862, Val Accuracy = 0.2855
# Iteration 499: Train Cost = 2.2858, Val Cost = 2.2859, Val Accuracy = 0.2884
# Accuracy: 0.2884
# Testing with learning rate: 0.001, hidden layer size: 100, lambda: 0.01
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.3014, Val Accuracy = 0.0979
# Iteration 10: Train Cost = 2.3011, Val Cost = 2.3012, Val Accuracy = 0.0982
# Iteration 20: Train Cost = 2.3009, Val Cost = 2.3009, Val Accuracy = 0.0986
# Iteration 30: Train Cost = 2.3006, Val Cost = 2.3006, Val Accuracy = 0.0990
# Iteration 40: Train Cost = 2.3003, Val Cost = 2.3004, Val Accuracy = 0.0998
# Iteration 50: Train Cost = 2.3001, Val Cost = 2.3001, Val Accuracy = 0.1003
# Iteration 60: Train Cost = 2.2998, Val Cost = 2.2998, Val Accuracy = 0.1014
# Iteration 70: Train Cost = 2.2995, Val Cost = 2.2996, Val Accuracy = 0.1024
# Iteration 80: Train Cost = 2.2993, Val Cost = 2.2993, Val Accuracy = 0.1032
# Iteration 90: Train Cost = 2.2990, Val Cost = 2.2990, Val Accuracy = 0.1048
# Iteration 100: Train Cost = 2.2987, Val Cost = 2.2988, Val Accuracy = 0.1059
# Iteration 110: Train Cost = 2.2984, Val Cost = 2.2985, Val Accuracy = 0.1080
# Iteration 120: Train Cost = 2.2982, Val Cost = 2.2982, Val Accuracy = 0.1098
# Iteration 130: Train Cost = 2.2979, Val Cost = 2.2979, Val Accuracy = 0.1116
# Iteration 140: Train Cost = 2.2976, Val Cost = 2.2977, Val Accuracy = 0.1140
# Iteration 150: Train Cost = 2.2973, Val Cost = 2.2974, Val Accuracy = 0.1169
# Iteration 160: Train Cost = 2.2971, Val Cost = 2.2971, Val Accuracy = 0.1209
# Iteration 170: Train Cost = 2.2968, Val Cost = 2.2968, Val Accuracy = 0.1245
# Iteration 180: Train Cost = 2.2965, Val Cost = 2.2965, Val Accuracy = 0.1281
# Iteration 190: Train Cost = 2.2962, Val Cost = 2.2962, Val Accuracy = 0.1313
# Iteration 200: Train Cost = 2.2959, Val Cost = 2.2960, Val Accuracy = 0.1357
# Iteration 210: Train Cost = 2.2956, Val Cost = 2.2957, Val Accuracy = 0.1400
# Iteration 220: Train Cost = 2.2953, Val Cost = 2.2954, Val Accuracy = 0.1447
# Iteration 230: Train Cost = 2.2950, Val Cost = 2.2951, Val Accuracy = 0.1499
# Iteration 240: Train Cost = 2.2947, Val Cost = 2.2948, Val Accuracy = 0.1555
# Iteration 250: Train Cost = 2.2944, Val Cost = 2.2945, Val Accuracy = 0.1606
# Iteration 260: Train Cost = 2.2941, Val Cost = 2.2942, Val Accuracy = 0.1660
# Iteration 270: Train Cost = 2.2938, Val Cost = 2.2939, Val Accuracy = 0.1717
# Iteration 280: Train Cost = 2.2935, Val Cost = 2.2936, Val Accuracy = 0.1773
# Iteration 290: Train Cost = 2.2932, Val Cost = 2.2932, Val Accuracy = 0.1842
# Iteration 300: Train Cost = 2.2929, Val Cost = 2.2929, Val Accuracy = 0.1894
# Iteration 310: Train Cost = 2.2925, Val Cost = 2.2926, Val Accuracy = 0.1945
# Iteration 320: Train Cost = 2.2922, Val Cost = 2.2923, Val Accuracy = 0.2003
# Iteration 330: Train Cost = 2.2919, Val Cost = 2.2920, Val Accuracy = 0.2059
# Iteration 340: Train Cost = 2.2916, Val Cost = 2.2916, Val Accuracy = 0.2123
# Iteration 350: Train Cost = 2.2912, Val Cost = 2.2913, Val Accuracy = 0.2173
# Iteration 360: Train Cost = 2.2909, Val Cost = 2.2910, Val Accuracy = 0.2239
# Iteration 370: Train Cost = 2.2905, Val Cost = 2.2906, Val Accuracy = 0.2286
# Iteration 380: Train Cost = 2.2902, Val Cost = 2.2903, Val Accuracy = 0.2345
# Iteration 390: Train Cost = 2.2899, Val Cost = 2.2899, Val Accuracy = 0.2398
# Iteration 400: Train Cost = 2.2895, Val Cost = 2.2896, Val Accuracy = 0.2449
# Iteration 410: Train Cost = 2.2891, Val Cost = 2.2892, Val Accuracy = 0.2493
# Iteration 420: Train Cost = 2.2888, Val Cost = 2.2889, Val Accuracy = 0.2545
# Iteration 430: Train Cost = 2.2884, Val Cost = 2.2885, Val Accuracy = 0.2583
# Iteration 440: Train Cost = 2.2881, Val Cost = 2.2881, Val Accuracy = 0.2633
# Iteration 450: Train Cost = 2.2877, Val Cost = 2.2878, Val Accuracy = 0.2690
# Iteration 460: Train Cost = 2.2873, Val Cost = 2.2874, Val Accuracy = 0.2755
# Iteration 470: Train Cost = 2.2869, Val Cost = 2.2870, Val Accuracy = 0.2794
# Iteration 480: Train Cost = 2.2865, Val Cost = 2.2866, Val Accuracy = 0.2829
# Iteration 490: Train Cost = 2.2861, Val Cost = 2.2862, Val Accuracy = 0.2855
# Iteration 499: Train Cost = 2.2858, Val Cost = 2.2859, Val Accuracy = 0.2884
# Accuracy: 0.2884
# Testing with learning rate: 0.001, hidden layer size: 100, lambda: 0.1
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.3015, Val Accuracy = 0.0979
# Iteration 10: Train Cost = 2.3011, Val Cost = 2.3012, Val Accuracy = 0.0982
# Iteration 20: Train Cost = 2.3009, Val Cost = 2.3009, Val Accuracy = 0.0986
# Iteration 30: Train Cost = 2.3006, Val Cost = 2.3007, Val Accuracy = 0.0990
# Iteration 40: Train Cost = 2.3003, Val Cost = 2.3004, Val Accuracy = 0.0998
# Iteration 50: Train Cost = 2.3001, Val Cost = 2.3001, Val Accuracy = 0.1003
# Iteration 60: Train Cost = 2.2998, Val Cost = 2.2999, Val Accuracy = 0.1014
# Iteration 70: Train Cost = 2.2995, Val Cost = 2.2996, Val Accuracy = 0.1024
# Iteration 80: Train Cost = 2.2993, Val Cost = 2.2993, Val Accuracy = 0.1032
# Iteration 90: Train Cost = 2.2990, Val Cost = 2.2991, Val Accuracy = 0.1048
# Iteration 100: Train Cost = 2.2987, Val Cost = 2.2988, Val Accuracy = 0.1059
# Iteration 110: Train Cost = 2.2985, Val Cost = 2.2985, Val Accuracy = 0.1080
# Iteration 120: Train Cost = 2.2982, Val Cost = 2.2983, Val Accuracy = 0.1098
# Iteration 130: Train Cost = 2.2979, Val Cost = 2.2980, Val Accuracy = 0.1116
# Iteration 140: Train Cost = 2.2976, Val Cost = 2.2977, Val Accuracy = 0.1140
# Iteration 150: Train Cost = 2.2973, Val Cost = 2.2974, Val Accuracy = 0.1169
# Iteration 160: Train Cost = 2.2971, Val Cost = 2.2971, Val Accuracy = 0.1209
# Iteration 170: Train Cost = 2.2968, Val Cost = 2.2969, Val Accuracy = 0.1245
# Iteration 180: Train Cost = 2.2965, Val Cost = 2.2966, Val Accuracy = 0.1281
# Iteration 190: Train Cost = 2.2962, Val Cost = 2.2963, Val Accuracy = 0.1313
# Iteration 200: Train Cost = 2.2959, Val Cost = 2.2960, Val Accuracy = 0.1357
# Iteration 210: Train Cost = 2.2956, Val Cost = 2.2957, Val Accuracy = 0.1400
# Iteration 220: Train Cost = 2.2953, Val Cost = 2.2954, Val Accuracy = 0.1447
# Iteration 230: Train Cost = 2.2950, Val Cost = 2.2951, Val Accuracy = 0.1499
# Iteration 240: Train Cost = 2.2947, Val Cost = 2.2948, Val Accuracy = 0.1555
# Iteration 250: Train Cost = 2.2944, Val Cost = 2.2945, Val Accuracy = 0.1606
# Iteration 260: Train Cost = 2.2941, Val Cost = 2.2942, Val Accuracy = 0.1660
# Iteration 270: Train Cost = 2.2938, Val Cost = 2.2939, Val Accuracy = 0.1717
# Iteration 280: Train Cost = 2.2935, Val Cost = 2.2936, Val Accuracy = 0.1773
# Iteration 290: Train Cost = 2.2932, Val Cost = 2.2933, Val Accuracy = 0.1842
# Iteration 300: Train Cost = 2.2929, Val Cost = 2.2930, Val Accuracy = 0.1894
# Iteration 310: Train Cost = 2.2925, Val Cost = 2.2926, Val Accuracy = 0.1945
# Iteration 320: Train Cost = 2.2922, Val Cost = 2.2923, Val Accuracy = 0.2003
# Iteration 330: Train Cost = 2.2919, Val Cost = 2.2920, Val Accuracy = 0.2059
# Iteration 340: Train Cost = 2.2916, Val Cost = 2.2917, Val Accuracy = 0.2123
# Iteration 350: Train Cost = 2.2912, Val Cost = 2.2913, Val Accuracy = 0.2173
# Iteration 360: Train Cost = 2.2909, Val Cost = 2.2910, Val Accuracy = 0.2239
# Iteration 370: Train Cost = 2.2906, Val Cost = 2.2907, Val Accuracy = 0.2286
# Iteration 380: Train Cost = 2.2902, Val Cost = 2.2903, Val Accuracy = 0.2345
# Iteration 390: Train Cost = 2.2899, Val Cost = 2.2900, Val Accuracy = 0.2398
# Iteration 400: Train Cost = 2.2895, Val Cost = 2.2896, Val Accuracy = 0.2449
# Iteration 410: Train Cost = 2.2892, Val Cost = 2.2893, Val Accuracy = 0.2493
# Iteration 420: Train Cost = 2.2888, Val Cost = 2.2889, Val Accuracy = 0.2545
# Iteration 430: Train Cost = 2.2884, Val Cost = 2.2885, Val Accuracy = 0.2583
# Iteration 440: Train Cost = 2.2881, Val Cost = 2.2882, Val Accuracy = 0.2633
# Iteration 450: Train Cost = 2.2877, Val Cost = 2.2878, Val Accuracy = 0.2690
# Iteration 460: Train Cost = 2.2873, Val Cost = 2.2874, Val Accuracy = 0.2755
# Iteration 470: Train Cost = 2.2869, Val Cost = 2.2870, Val Accuracy = 0.2794
# Iteration 480: Train Cost = 2.2865, Val Cost = 2.2867, Val Accuracy = 0.2829
# Iteration 490: Train Cost = 2.2862, Val Cost = 2.2863, Val Accuracy = 0.2855
# Iteration 499: Train Cost = 2.2858, Val Cost = 2.2859, Val Accuracy = 0.2884
# Accuracy: 0.2884
# Testing with learning rate: 0.001, hidden layer size: 150, lambda: 0.001
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.3015, Val Accuracy = 0.1788
# Iteration 10: Train Cost = 2.3010, Val Cost = 2.3011, Val Accuracy = 0.1900
# Iteration 20: Train Cost = 2.3006, Val Cost = 2.3007, Val Accuracy = 0.1999
# Iteration 30: Train Cost = 2.3002, Val Cost = 2.3002, Val Accuracy = 0.2093
# Iteration 40: Train Cost = 2.2998, Val Cost = 2.2998, Val Accuracy = 0.2167
# Iteration 50: Train Cost = 2.2994, Val Cost = 2.2994, Val Accuracy = 0.2226
# Iteration 60: Train Cost = 2.2990, Val Cost = 2.2990, Val Accuracy = 0.2298
# Iteration 70: Train Cost = 2.2986, Val Cost = 2.2986, Val Accuracy = 0.2361
# Iteration 80: Train Cost = 2.2982, Val Cost = 2.2982, Val Accuracy = 0.2403
# Iteration 90: Train Cost = 2.2978, Val Cost = 2.2978, Val Accuracy = 0.2442
# Iteration 100: Train Cost = 2.2974, Val Cost = 2.2974, Val Accuracy = 0.2489
# Iteration 110: Train Cost = 2.2970, Val Cost = 2.2970, Val Accuracy = 0.2535
# Iteration 120: Train Cost = 2.2966, Val Cost = 2.2966, Val Accuracy = 0.2571
# Iteration 130: Train Cost = 2.2962, Val Cost = 2.2962, Val Accuracy = 0.2605
# Iteration 140: Train Cost = 2.2957, Val Cost = 2.2958, Val Accuracy = 0.2630
# Iteration 150: Train Cost = 2.2953, Val Cost = 2.2954, Val Accuracy = 0.2674
# Iteration 160: Train Cost = 2.2949, Val Cost = 2.2950, Val Accuracy = 0.2705
# Iteration 170: Train Cost = 2.2945, Val Cost = 2.2946, Val Accuracy = 0.2728
# Iteration 180: Train Cost = 2.2941, Val Cost = 2.2941, Val Accuracy = 0.2753
# Iteration 190: Train Cost = 2.2937, Val Cost = 2.2937, Val Accuracy = 0.2772
# Iteration 200: Train Cost = 2.2933, Val Cost = 2.2933, Val Accuracy = 0.2792
# Iteration 210: Train Cost = 2.2928, Val Cost = 2.2929, Val Accuracy = 0.2825
# Iteration 220: Train Cost = 2.2924, Val Cost = 2.2925, Val Accuracy = 0.2860
# Iteration 230: Train Cost = 2.2920, Val Cost = 2.2921, Val Accuracy = 0.2894
# Iteration 240: Train Cost = 2.2916, Val Cost = 2.2916, Val Accuracy = 0.2906
# Iteration 250: Train Cost = 2.2911, Val Cost = 2.2912, Val Accuracy = 0.2937
# Iteration 260: Train Cost = 2.2907, Val Cost = 2.2908, Val Accuracy = 0.2969
# Iteration 270: Train Cost = 2.2903, Val Cost = 2.2903, Val Accuracy = 0.3002
# Iteration 280: Train Cost = 2.2898, Val Cost = 2.2899, Val Accuracy = 0.3036
# Iteration 290: Train Cost = 2.2894, Val Cost = 2.2895, Val Accuracy = 0.3070
# Iteration 300: Train Cost = 2.2890, Val Cost = 2.2890, Val Accuracy = 0.3099
# Iteration 310: Train Cost = 2.2885, Val Cost = 2.2886, Val Accuracy = 0.3127
# Iteration 320: Train Cost = 2.2881, Val Cost = 2.2881, Val Accuracy = 0.3146
# Iteration 330: Train Cost = 2.2876, Val Cost = 2.2877, Val Accuracy = 0.3177
# Iteration 340: Train Cost = 2.2871, Val Cost = 2.2872, Val Accuracy = 0.3216
# Iteration 350: Train Cost = 2.2867, Val Cost = 2.2868, Val Accuracy = 0.3242
# Iteration 360: Train Cost = 2.2862, Val Cost = 2.2863, Val Accuracy = 0.3259
# Iteration 370: Train Cost = 2.2857, Val Cost = 2.2858, Val Accuracy = 0.3283
# Iteration 380: Train Cost = 2.2853, Val Cost = 2.2854, Val Accuracy = 0.3301
# Iteration 390: Train Cost = 2.2848, Val Cost = 2.2849, Val Accuracy = 0.3331
# Iteration 400: Train Cost = 2.2843, Val Cost = 2.2844, Val Accuracy = 0.3360
# Iteration 410: Train Cost = 2.2838, Val Cost = 2.2839, Val Accuracy = 0.3369
# Iteration 420: Train Cost = 2.2833, Val Cost = 2.2834, Val Accuracy = 0.3392
# Iteration 430: Train Cost = 2.2828, Val Cost = 2.2829, Val Accuracy = 0.3416
# Iteration 440: Train Cost = 2.2823, Val Cost = 2.2824, Val Accuracy = 0.3436
# Iteration 450: Train Cost = 2.2818, Val Cost = 2.2819, Val Accuracy = 0.3449
# Iteration 460: Train Cost = 2.2813, Val Cost = 2.2814, Val Accuracy = 0.3466
# Iteration 470: Train Cost = 2.2808, Val Cost = 2.2809, Val Accuracy = 0.3484
# Iteration 480: Train Cost = 2.2802, Val Cost = 2.2803, Val Accuracy = 0.3501
# Iteration 490: Train Cost = 2.2797, Val Cost = 2.2798, Val Accuracy = 0.3507
# Iteration 499: Train Cost = 2.2792, Val Cost = 2.2793, Val Accuracy = 0.3509
# Accuracy: 0.3509
# Testing with learning rate: 0.001, hidden layer size: 150, lambda: 0.01
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.3015, Val Accuracy = 0.1788
# Iteration 10: Train Cost = 2.3010, Val Cost = 2.3011, Val Accuracy = 0.1900
# Iteration 20: Train Cost = 2.3006, Val Cost = 2.3007, Val Accuracy = 0.1999
# Iteration 30: Train Cost = 2.3002, Val Cost = 2.3003, Val Accuracy = 0.2093
# Iteration 40: Train Cost = 2.2998, Val Cost = 2.2998, Val Accuracy = 0.2167
# Iteration 50: Train Cost = 2.2994, Val Cost = 2.2994, Val Accuracy = 0.2226
# Iteration 60: Train Cost = 2.2990, Val Cost = 2.2990, Val Accuracy = 0.2298
# Iteration 70: Train Cost = 2.2986, Val Cost = 2.2986, Val Accuracy = 0.2361
# Iteration 80: Train Cost = 2.2982, Val Cost = 2.2982, Val Accuracy = 0.2403
# Iteration 90: Train Cost = 2.2978, Val Cost = 2.2978, Val Accuracy = 0.2442
# Iteration 100: Train Cost = 2.2974, Val Cost = 2.2974, Val Accuracy = 0.2489
# Iteration 110: Train Cost = 2.2970, Val Cost = 2.2970, Val Accuracy = 0.2535
# Iteration 120: Train Cost = 2.2966, Val Cost = 2.2966, Val Accuracy = 0.2571
# Iteration 130: Train Cost = 2.2962, Val Cost = 2.2962, Val Accuracy = 0.2605
# Iteration 140: Train Cost = 2.2957, Val Cost = 2.2958, Val Accuracy = 0.2630
# Iteration 150: Train Cost = 2.2953, Val Cost = 2.2954, Val Accuracy = 0.2674
# Iteration 160: Train Cost = 2.2949, Val Cost = 2.2950, Val Accuracy = 0.2705
# Iteration 170: Train Cost = 2.2945, Val Cost = 2.2946, Val Accuracy = 0.2728
# Iteration 180: Train Cost = 2.2941, Val Cost = 2.2942, Val Accuracy = 0.2753
# Iteration 190: Train Cost = 2.2937, Val Cost = 2.2937, Val Accuracy = 0.2772
# Iteration 200: Train Cost = 2.2933, Val Cost = 2.2933, Val Accuracy = 0.2792
# Iteration 210: Train Cost = 2.2928, Val Cost = 2.2929, Val Accuracy = 0.2825
# Iteration 220: Train Cost = 2.2924, Val Cost = 2.2925, Val Accuracy = 0.2860
# Iteration 230: Train Cost = 2.2920, Val Cost = 2.2921, Val Accuracy = 0.2894
# Iteration 240: Train Cost = 2.2916, Val Cost = 2.2916, Val Accuracy = 0.2906
# Iteration 250: Train Cost = 2.2911, Val Cost = 2.2912, Val Accuracy = 0.2937
# Iteration 260: Train Cost = 2.2907, Val Cost = 2.2908, Val Accuracy = 0.2969
# Iteration 270: Train Cost = 2.2903, Val Cost = 2.2904, Val Accuracy = 0.3002
# Iteration 280: Train Cost = 2.2898, Val Cost = 2.2899, Val Accuracy = 0.3036
# Iteration 290: Train Cost = 2.2894, Val Cost = 2.2895, Val Accuracy = 0.3070
# Iteration 300: Train Cost = 2.2890, Val Cost = 2.2890, Val Accuracy = 0.3099
# Iteration 310: Train Cost = 2.2885, Val Cost = 2.2886, Val Accuracy = 0.3127
# Iteration 320: Train Cost = 2.2881, Val Cost = 2.2881, Val Accuracy = 0.3146
# Iteration 330: Train Cost = 2.2876, Val Cost = 2.2877, Val Accuracy = 0.3177
# Iteration 340: Train Cost = 2.2871, Val Cost = 2.2872, Val Accuracy = 0.3216
# Iteration 350: Train Cost = 2.2867, Val Cost = 2.2868, Val Accuracy = 0.3242
# Iteration 360: Train Cost = 2.2862, Val Cost = 2.2863, Val Accuracy = 0.3259
# Iteration 370: Train Cost = 2.2858, Val Cost = 2.2858, Val Accuracy = 0.3283
# Iteration 380: Train Cost = 2.2853, Val Cost = 2.2854, Val Accuracy = 0.3301
# Iteration 390: Train Cost = 2.2848, Val Cost = 2.2849, Val Accuracy = 0.3331
# Iteration 400: Train Cost = 2.2843, Val Cost = 2.2844, Val Accuracy = 0.3360
# Iteration 410: Train Cost = 2.2838, Val Cost = 2.2839, Val Accuracy = 0.3369
# Iteration 420: Train Cost = 2.2833, Val Cost = 2.2834, Val Accuracy = 0.3392
# Iteration 430: Train Cost = 2.2828, Val Cost = 2.2829, Val Accuracy = 0.3416
# Iteration 440: Train Cost = 2.2823, Val Cost = 2.2824, Val Accuracy = 0.3436
# Iteration 450: Train Cost = 2.2818, Val Cost = 2.2819, Val Accuracy = 0.3449
# Iteration 460: Train Cost = 2.2813, Val Cost = 2.2814, Val Accuracy = 0.3466
# Iteration 470: Train Cost = 2.2808, Val Cost = 2.2809, Val Accuracy = 0.3484
# Iteration 480: Train Cost = 2.2802, Val Cost = 2.2803, Val Accuracy = 0.3501
# Iteration 490: Train Cost = 2.2797, Val Cost = 2.2798, Val Accuracy = 0.3507
# Iteration 499: Train Cost = 2.2792, Val Cost = 2.2793, Val Accuracy = 0.3509
# Accuracy: 0.3509
# Testing with learning rate: 0.001, hidden layer size: 150, lambda: 0.1
# Iteration 0: Train Cost = 2.3015, Val Cost = 2.3015, Val Accuracy = 0.1788
# Iteration 10: Train Cost = 2.3010, Val Cost = 2.3011, Val Accuracy = 0.1900
# Iteration 20: Train Cost = 2.3006, Val Cost = 2.3007, Val Accuracy = 0.1999
# Iteration 30: Train Cost = 2.3002, Val Cost = 2.3003, Val Accuracy = 0.2093
# Iteration 40: Train Cost = 2.2998, Val Cost = 2.2999, Val Accuracy = 0.2167
# Iteration 50: Train Cost = 2.2994, Val Cost = 2.2995, Val Accuracy = 0.2226
# Iteration 60: Train Cost = 2.2990, Val Cost = 2.2991, Val Accuracy = 0.2298
# Iteration 70: Train Cost = 2.2986, Val Cost = 2.2987, Val Accuracy = 0.2361
# Iteration 80: Train Cost = 2.2982, Val Cost = 2.2983, Val Accuracy = 0.2403
# Iteration 90: Train Cost = 2.2978, Val Cost = 2.2979, Val Accuracy = 0.2442
# Iteration 100: Train Cost = 2.2974, Val Cost = 2.2975, Val Accuracy = 0.2489
# Iteration 110: Train Cost = 2.2970, Val Cost = 2.2971, Val Accuracy = 0.2535
# Iteration 120: Train Cost = 2.2966, Val Cost = 2.2967, Val Accuracy = 0.2571
# Iteration 130: Train Cost = 2.2962, Val Cost = 2.2963, Val Accuracy = 0.2605
# Iteration 140: Train Cost = 2.2958, Val Cost = 2.2958, Val Accuracy = 0.2630
# Iteration 150: Train Cost = 2.2953, Val Cost = 2.2954, Val Accuracy = 0.2674
# Iteration 160: Train Cost = 2.2949, Val Cost = 2.2950, Val Accuracy = 0.2705
# Iteration 170: Train Cost = 2.2945, Val Cost = 2.2946, Val Accuracy = 0.2728
# Iteration 180: Train Cost = 2.2941, Val Cost = 2.2942, Val Accuracy = 0.2753
# Iteration 190: Train Cost = 2.2937, Val Cost = 2.2938, Val Accuracy = 0.2772
# Iteration 200: Train Cost = 2.2933, Val Cost = 2.2934, Val Accuracy = 0.2792
# Iteration 210: Train Cost = 2.2929, Val Cost = 2.2930, Val Accuracy = 0.2825
# Iteration 220: Train Cost = 2.2924, Val Cost = 2.2925, Val Accuracy = 0.2860
# Iteration 230: Train Cost = 2.2920, Val Cost = 2.2921, Val Accuracy = 0.2894
# Iteration 240: Train Cost = 2.2916, Val Cost = 2.2917, Val Accuracy = 0.2906
# Iteration 250: Train Cost = 2.2912, Val Cost = 2.2913, Val Accuracy = 0.2937
# Iteration 260: Train Cost = 2.2907, Val Cost = 2.2908, Val Accuracy = 0.2969
# Iteration 270: Train Cost = 2.2903, Val Cost = 2.2904, Val Accuracy = 0.3002
# Iteration 280: Train Cost = 2.2899, Val Cost = 2.2900, Val Accuracy = 0.3036
# Iteration 290: Train Cost = 2.2894, Val Cost = 2.2895, Val Accuracy = 0.3070
# Iteration 300: Train Cost = 2.2890, Val Cost = 2.2891, Val Accuracy = 0.3099
# Iteration 310: Train Cost = 2.2885, Val Cost = 2.2886, Val Accuracy = 0.3127
# Iteration 320: Train Cost = 2.2881, Val Cost = 2.2882, Val Accuracy = 0.3146
# Iteration 330: Train Cost = 2.2876, Val Cost = 2.2877, Val Accuracy = 0.3177
# Iteration 340: Train Cost = 2.2872, Val Cost = 2.2873, Val Accuracy = 0.3216
# Iteration 350: Train Cost = 2.2867, Val Cost = 2.2868, Val Accuracy = 0.3242
# Iteration 360: Train Cost = 2.2862, Val Cost = 2.2864, Val Accuracy = 0.3259
# Iteration 370: Train Cost = 2.2858, Val Cost = 2.2859, Val Accuracy = 0.3283
# Iteration 380: Train Cost = 2.2853, Val Cost = 2.2854, Val Accuracy = 0.3301
# Iteration 390: Train Cost = 2.2848, Val Cost = 2.2849, Val Accuracy = 0.3331
# Iteration 400: Train Cost = 2.2843, Val Cost = 2.2845, Val Accuracy = 0.3360
# Iteration 410: Train Cost = 2.2838, Val Cost = 2.2840, Val Accuracy = 0.3369
# Iteration 420: Train Cost = 2.2833, Val Cost = 2.2835, Val Accuracy = 0.3392
# Iteration 430: Train Cost = 2.2828, Val Cost = 2.2830, Val Accuracy = 0.3416
# Iteration 440: Train Cost = 2.2823, Val Cost = 2.2825, Val Accuracy = 0.3436
# Iteration 450: Train Cost = 2.2818, Val Cost = 2.2820, Val Accuracy = 0.3449
# Iteration 460: Train Cost = 2.2813, Val Cost = 2.2814, Val Accuracy = 0.3466
# Iteration 470: Train Cost = 2.2808, Val Cost = 2.2809, Val Accuracy = 0.3484
# Iteration 480: Train Cost = 2.2803, Val Cost = 2.2804, Val Accuracy = 0.3501
# Iteration 490: Train Cost = 2.2797, Val Cost = 2.2799, Val Accuracy = 0.3507
# Iteration 499: Train Cost = 2.2792, Val Cost = 2.2794, Val Accuracy = 0.3509
# Accuracy: 0.3509
# Testing with learning rate: 0.01, hidden layer size: 50, lambda: 0.001
# Iteration 0: Train Cost = 2.3027, Val Cost = 2.3025, Val Accuracy = 0.1452
# Iteration 10: Train Cost = 2.3011, Val Cost = 2.3009, Val Accuracy = 0.1661
# Iteration 20: Train Cost = 2.2996, Val Cost = 2.2994, Val Accuracy = 0.1805
# Iteration 30: Train Cost = 2.2979, Val Cost = 2.2977, Val Accuracy = 0.1972
# Iteration 40: Train Cost = 2.2961, Val Cost = 2.2959, Val Accuracy = 0.2130
# Iteration 50: Train Cost = 2.2941, Val Cost = 2.2939, Val Accuracy = 0.2280
# Iteration 60: Train Cost = 2.2918, Val Cost = 2.2915, Val Accuracy = 0.2442
# Iteration 70: Train Cost = 2.2892, Val Cost = 2.2888, Val Accuracy = 0.2482
# Iteration 80: Train Cost = 2.2861, Val Cost = 2.2857, Val Accuracy = 0.2494
# Iteration 90: Train Cost = 2.2824, Val Cost = 2.2820, Val Accuracy = 0.2515
# Iteration 100: Train Cost = 2.2782, Val Cost = 2.2776, Val Accuracy = 0.2513
# Iteration 110: Train Cost = 2.2732, Val Cost = 2.2726, Val Accuracy = 0.2499
# Iteration 120: Train Cost = 2.2674, Val Cost = 2.2667, Val Accuracy = 0.2488
# Iteration 130: Train Cost = 2.2607, Val Cost = 2.2600, Val Accuracy = 0.2481
# Iteration 140: Train Cost = 2.2531, Val Cost = 2.2522, Val Accuracy = 0.2460
# Iteration 150: Train Cost = 2.2444, Val Cost = 2.2434, Val Accuracy = 0.2460
# Iteration 160: Train Cost = 2.2347, Val Cost = 2.2336, Val Accuracy = 0.2440
# Iteration 170: Train Cost = 2.2238, Val Cost = 2.2226, Val Accuracy = 0.2448
# Iteration 180: Train Cost = 2.2119, Val Cost = 2.2106, Val Accuracy = 0.2441
# Iteration 190: Train Cost = 2.1989, Val Cost = 2.1975, Val Accuracy = 0.2426
# Iteration 200: Train Cost = 2.1848, Val Cost = 2.1833, Val Accuracy = 0.2427
# Iteration 210: Train Cost = 2.1697, Val Cost = 2.1681, Val Accuracy = 0.2443
# Iteration 220: Train Cost = 2.1534, Val Cost = 2.1518, Val Accuracy = 0.2458
# Iteration 230: Train Cost = 2.1361, Val Cost = 2.1344, Val Accuracy = 0.2487
# Iteration 240: Train Cost = 2.1177, Val Cost = 2.1159, Val Accuracy = 0.2518
# Iteration 250: Train Cost = 2.0981, Val Cost = 2.0962, Val Accuracy = 0.2545
# Iteration 260: Train Cost = 2.0772, Val Cost = 2.0753, Val Accuracy = 0.2576
# Iteration 270: Train Cost = 2.0550, Val Cost = 2.0531, Val Accuracy = 0.2609
# Iteration 280: Train Cost = 2.0315, Val Cost = 2.0295, Val Accuracy = 0.2640
# Iteration 290: Train Cost = 2.0067, Val Cost = 2.0048, Val Accuracy = 0.2665
# Iteration 300: Train Cost = 1.9808, Val Cost = 1.9789, Val Accuracy = 0.2699
# Iteration 310: Train Cost = 1.9539, Val Cost = 1.9520, Val Accuracy = 0.2854
# Iteration 320: Train Cost = 1.9262, Val Cost = 1.9245, Val Accuracy = 0.3392
# Iteration 330: Train Cost = 1.8981, Val Cost = 1.8965, Val Accuracy = 0.3749
# Iteration 340: Train Cost = 1.8699, Val Cost = 1.8684, Val Accuracy = 0.3849
# Iteration 350: Train Cost = 1.8418, Val Cost = 1.8405, Val Accuracy = 0.3913
# Iteration 360: Train Cost = 1.8140, Val Cost = 1.8129, Val Accuracy = 0.3955
# Iteration 370: Train Cost = 1.7866, Val Cost = 1.7858, Val Accuracy = 0.3983
# Iteration 380: Train Cost = 1.7599, Val Cost = 1.7592, Val Accuracy = 0.4037
# Iteration 390: Train Cost = 1.7338, Val Cost = 1.7333, Val Accuracy = 0.4102
# Iteration 400: Train Cost = 1.7083, Val Cost = 1.7081, Val Accuracy = 0.4170
# Iteration 410: Train Cost = 1.6836, Val Cost = 1.6836, Val Accuracy = 0.4207
# Iteration 420: Train Cost = 1.6596, Val Cost = 1.6599, Val Accuracy = 0.4242
# Iteration 430: Train Cost = 1.6363, Val Cost = 1.6368, Val Accuracy = 0.4288
# Iteration 440: Train Cost = 1.6138, Val Cost = 1.6146, Val Accuracy = 0.4353
# Iteration 450: Train Cost = 1.5921, Val Cost = 1.5930, Val Accuracy = 0.4403
# Iteration 460: Train Cost = 1.5710, Val Cost = 1.5722, Val Accuracy = 0.4458
# Iteration 470: Train Cost = 1.5507, Val Cost = 1.5522, Val Accuracy = 0.4519
# Iteration 480: Train Cost = 1.5311, Val Cost = 1.5328, Val Accuracy = 0.4561
# Iteration 490: Train Cost = 1.5122, Val Cost = 1.5141, Val Accuracy = 0.4607
# Iteration 499: Train Cost = 1.4957, Val Cost = 1.4979, Val Accuracy = 0.4662
# Accuracy: 0.4662
# Testing with learning rate: 0.01, hidden layer size: 50, lambda: 0.01
# Iteration 0: Train Cost = 2.3027, Val Cost = 2.3025, Val Accuracy = 0.1452
# Iteration 10: Train Cost = 2.3011, Val Cost = 2.3009, Val Accuracy = 0.1661
# Iteration 20: Train Cost = 2.2996, Val Cost = 2.2994, Val Accuracy = 0.1805
# Iteration 30: Train Cost = 2.2979, Val Cost = 2.2977, Val Accuracy = 0.1972
# Iteration 40: Train Cost = 2.2961, Val Cost = 2.2959, Val Accuracy = 0.2130
# Iteration 50: Train Cost = 2.2941, Val Cost = 2.2939, Val Accuracy = 0.2280
# Iteration 60: Train Cost = 2.2918, Val Cost = 2.2915, Val Accuracy = 0.2442
# Iteration 70: Train Cost = 2.2892, Val Cost = 2.2888, Val Accuracy = 0.2482
# Iteration 80: Train Cost = 2.2861, Val Cost = 2.2857, Val Accuracy = 0.2494
# Iteration 90: Train Cost = 2.2824, Val Cost = 2.2820, Val Accuracy = 0.2515
# Iteration 100: Train Cost = 2.2782, Val Cost = 2.2776, Val Accuracy = 0.2513
# Iteration 110: Train Cost = 2.2732, Val Cost = 2.2726, Val Accuracy = 0.2499
# Iteration 120: Train Cost = 2.2674, Val Cost = 2.2667, Val Accuracy = 0.2488
# Iteration 130: Train Cost = 2.2607, Val Cost = 2.2600, Val Accuracy = 0.2481
# Iteration 140: Train Cost = 2.2531, Val Cost = 2.2522, Val Accuracy = 0.2460
# Iteration 150: Train Cost = 2.2444, Val Cost = 2.2434, Val Accuracy = 0.2460
# Iteration 160: Train Cost = 2.2347, Val Cost = 2.2336, Val Accuracy = 0.2440
# Iteration 170: Train Cost = 2.2238, Val Cost = 2.2226, Val Accuracy = 0.2448
# Iteration 180: Train Cost = 2.2119, Val Cost = 2.2106, Val Accuracy = 0.2441
# Iteration 190: Train Cost = 2.1989, Val Cost = 2.1975, Val Accuracy = 0.2426
# Iteration 200: Train Cost = 2.1848, Val Cost = 2.1833, Val Accuracy = 0.2427
# Iteration 210: Train Cost = 2.1697, Val Cost = 2.1681, Val Accuracy = 0.2443
# Iteration 220: Train Cost = 2.1534, Val Cost = 2.1518, Val Accuracy = 0.2458
# Iteration 230: Train Cost = 2.1361, Val Cost = 2.1344, Val Accuracy = 0.2487
# Iteration 240: Train Cost = 2.1177, Val Cost = 2.1159, Val Accuracy = 0.2518
# Iteration 250: Train Cost = 2.0981, Val Cost = 2.0962, Val Accuracy = 0.2545
# Iteration 260: Train Cost = 2.0772, Val Cost = 2.0753, Val Accuracy = 0.2576
# Iteration 270: Train Cost = 2.0550, Val Cost = 2.0531, Val Accuracy = 0.2609
# Iteration 280: Train Cost = 2.0315, Val Cost = 2.0295, Val Accuracy = 0.2640
# Iteration 290: Train Cost = 2.0067, Val Cost = 2.0048, Val Accuracy = 0.2665
# Iteration 300: Train Cost = 1.9808, Val Cost = 1.9789, Val Accuracy = 0.2699
# Iteration 310: Train Cost = 1.9539, Val Cost = 1.9520, Val Accuracy = 0.2854
# Iteration 320: Train Cost = 1.9262, Val Cost = 1.9245, Val Accuracy = 0.3392
# Iteration 330: Train Cost = 1.8981, Val Cost = 1.8965, Val Accuracy = 0.3749
# Iteration 340: Train Cost = 1.8699, Val Cost = 1.8684, Val Accuracy = 0.3849
# Iteration 350: Train Cost = 1.8418, Val Cost = 1.8405, Val Accuracy = 0.3913
# Iteration 360: Train Cost = 1.8140, Val Cost = 1.8129, Val Accuracy = 0.3955
# Iteration 370: Train Cost = 1.7866, Val Cost = 1.7858, Val Accuracy = 0.3983
# Iteration 380: Train Cost = 1.7599, Val Cost = 1.7592, Val Accuracy = 0.4037
# Iteration 390: Train Cost = 1.7338, Val Cost = 1.7333, Val Accuracy = 0.4102
# Iteration 400: Train Cost = 1.7083, Val Cost = 1.7081, Val Accuracy = 0.4170
# Iteration 410: Train Cost = 1.6836, Val Cost = 1.6836, Val Accuracy = 0.4207
# Iteration 420: Train Cost = 1.6596, Val Cost = 1.6599, Val Accuracy = 0.4242
# Iteration 430: Train Cost = 1.6363, Val Cost = 1.6368, Val Accuracy = 0.4288
# Iteration 440: Train Cost = 1.6138, Val Cost = 1.6146, Val Accuracy = 0.4353
# Iteration 450: Train Cost = 1.5921, Val Cost = 1.5930, Val Accuracy = 0.4403
# Iteration 460: Train Cost = 1.5710, Val Cost = 1.5722, Val Accuracy = 0.4458
# Iteration 470: Train Cost = 1.5507, Val Cost = 1.5522, Val Accuracy = 0.4519
# Iteration 480: Train Cost = 1.5311, Val Cost = 1.5328, Val Accuracy = 0.4561
# Iteration 490: Train Cost = 1.5122, Val Cost = 1.5141, Val Accuracy = 0.4607
# Iteration 499: Train Cost = 1.4957, Val Cost = 1.4979, Val Accuracy = 0.4662
# Accuracy: 0.4662
# Testing with learning rate: 0.01, hidden layer size: 50, lambda: 0.1
# Iteration 0: Train Cost = 2.3027, Val Cost = 2.3025, Val Accuracy = 0.1452
# Iteration 10: Train Cost = 2.3011, Val Cost = 2.3010, Val Accuracy = 0.1661
# Iteration 20: Train Cost = 2.2996, Val Cost = 2.2994, Val Accuracy = 0.1805
# Iteration 30: Train Cost = 2.2979, Val Cost = 2.2977, Val Accuracy = 0.1972
# Iteration 40: Train Cost = 2.2961, Val Cost = 2.2959, Val Accuracy = 0.2130
# Iteration 50: Train Cost = 2.2941, Val Cost = 2.2939, Val Accuracy = 0.2280
# Iteration 60: Train Cost = 2.2918, Val Cost = 2.2916, Val Accuracy = 0.2442
# Iteration 70: Train Cost = 2.2892, Val Cost = 2.2889, Val Accuracy = 0.2482
# Iteration 80: Train Cost = 2.2861, Val Cost = 2.2857, Val Accuracy = 0.2494
# Iteration 90: Train Cost = 2.2824, Val Cost = 2.2820, Val Accuracy = 0.2515
# Iteration 100: Train Cost = 2.2782, Val Cost = 2.2777, Val Accuracy = 0.2513
# Iteration 110: Train Cost = 2.2732, Val Cost = 2.2726, Val Accuracy = 0.2499
# Iteration 120: Train Cost = 2.2674, Val Cost = 2.2667, Val Accuracy = 0.2488
# Iteration 130: Train Cost = 2.2607, Val Cost = 2.2600, Val Accuracy = 0.2481
# Iteration 140: Train Cost = 2.2531, Val Cost = 2.2522, Val Accuracy = 0.2460
# Iteration 150: Train Cost = 2.2444, Val Cost = 2.2435, Val Accuracy = 0.2460
# Iteration 160: Train Cost = 2.2347, Val Cost = 2.2336, Val Accuracy = 0.2440
# Iteration 170: Train Cost = 2.2238, Val Cost = 2.2227, Val Accuracy = 0.2448
# Iteration 180: Train Cost = 2.2119, Val Cost = 2.2106, Val Accuracy = 0.2441
# Iteration 190: Train Cost = 2.1989, Val Cost = 2.1975, Val Accuracy = 0.2426
# Iteration 200: Train Cost = 2.1848, Val Cost = 2.1833, Val Accuracy = 0.2427
# Iteration 210: Train Cost = 2.1697, Val Cost = 2.1681, Val Accuracy = 0.2443
# Iteration 220: Train Cost = 2.1535, Val Cost = 2.1518, Val Accuracy = 0.2458
# Iteration 230: Train Cost = 2.1361, Val Cost = 2.1345, Val Accuracy = 0.2487
# Iteration 240: Train Cost = 2.1177, Val Cost = 2.1160, Val Accuracy = 0.2518
# Iteration 250: Train Cost = 2.0981, Val Cost = 2.0963, Val Accuracy = 0.2545
# Iteration 260: Train Cost = 2.0772, Val Cost = 2.0753, Val Accuracy = 0.2576
# Iteration 270: Train Cost = 2.0550, Val Cost = 2.0531, Val Accuracy = 0.2609
# Iteration 280: Train Cost = 2.0315, Val Cost = 2.0296, Val Accuracy = 0.2640
# Iteration 290: Train Cost = 2.0067, Val Cost = 2.0048, Val Accuracy = 0.2665
# Iteration 300: Train Cost = 1.9808, Val Cost = 1.9789, Val Accuracy = 0.2699
# Iteration 310: Train Cost = 1.9539, Val Cost = 1.9520, Val Accuracy = 0.2854
# Iteration 320: Train Cost = 1.9262, Val Cost = 1.9245, Val Accuracy = 0.3392
# Iteration 330: Train Cost = 1.8981, Val Cost = 1.8965, Val Accuracy = 0.3749
# Iteration 340: Train Cost = 1.8699, Val Cost = 1.8684, Val Accuracy = 0.3849
# Iteration 350: Train Cost = 1.8418, Val Cost = 1.8405, Val Accuracy = 0.3913
# Iteration 360: Train Cost = 1.8140, Val Cost = 1.8129, Val Accuracy = 0.3955
# Iteration 370: Train Cost = 1.7866, Val Cost = 1.7858, Val Accuracy = 0.3983
# Iteration 380: Train Cost = 1.7599, Val Cost = 1.7592, Val Accuracy = 0.4037
# Iteration 390: Train Cost = 1.7338, Val Cost = 1.7333, Val Accuracy = 0.4102
# Iteration 400: Train Cost = 1.7083, Val Cost = 1.7081, Val Accuracy = 0.4169
# Iteration 410: Train Cost = 1.6836, Val Cost = 1.6836, Val Accuracy = 0.4207
# Iteration 420: Train Cost = 1.6596, Val Cost = 1.6599, Val Accuracy = 0.4242
# Iteration 430: Train Cost = 1.6363, Val Cost = 1.6369, Val Accuracy = 0.4288
# Iteration 440: Train Cost = 1.6138, Val Cost = 1.6146, Val Accuracy = 0.4353
# Iteration 450: Train Cost = 1.5921, Val Cost = 1.5931, Val Accuracy = 0.4403
# Iteration 460: Train Cost = 1.5710, Val Cost = 1.5723, Val Accuracy = 0.4458
# Iteration 470: Train Cost = 1.5507, Val Cost = 1.5522, Val Accuracy = 0.4519
# Iteration 480: Train Cost = 1.5311, Val Cost = 1.5328, Val Accuracy = 0.4561
# Iteration 490: Train Cost = 1.5122, Val Cost = 1.5142, Val Accuracy = 0.4607
# ...
# Iteration 10: Train Cost = 2.2608, Val Cost = 2.2536, Val Accuracy = 0.3759
# Iteration 20: Train Cost = 2.1238, Val Cost = 2.1016, Val Accuracy = 0.3189
# Iteration 30: Train Cost = 1.8279, Val Cost = 1.7974, Val Accuracy = 0.4057
# Iteration 40: Train Cost = 1.5409, Val Cost = 1.5216, Val Accuracy = 0.5256
# Iteration 50: Train Cost = 1.3446, Val Cost = 1.3344, Val Accuracy = 0.5772
# Iteration 60: Train Cost = 1.2053, Val Cost = 1.2009, Val Accuracy = 0.6020
# Iteration 70: Train Cost = 1.1008, Val Cost = 1.1008, Val Accuracy = 0.6191
# Iteration 80: Train Cost = 1.0213, Val Cost = 1.0247, Val Accuracy = 0.6361
# Iteration 90: Train Cost = 0.9597, Val Cost = 0.9659, Val Accuracy = 0.6490
# Iteration 100: Train Cost = 0.9112, Val Cost = 0.9196, Val Accuracy = 0.6598
# Iteration 110: Train Cost = 0.8724, Val Cost = 0.8827, Val Accuracy = 0.6675
# Iteration 120: Train Cost = 0.8409, Val Cost = 0.8526, Val Accuracy = 0.6753
# Iteration 130: Train Cost = 0.8148, Val Cost = 0.8278, Val Accuracy = 0.6831
# Iteration 140: Train Cost = 0.7994, Val Cost = 0.8221, Val Accuracy = 0.6674
# Iteration 150: Train Cost = 0.8239, Val Cost = 0.8531, Val Accuracy = 0.6626
# Iteration 160: Train Cost = 0.7958, Val Cost = 0.8208, Val Accuracy = 0.6708
# Iteration 170: Train Cost = 0.7751, Val Cost = 0.7985, Val Accuracy = 0.6819
# Iteration 180: Train Cost = 0.7583, Val Cost = 0.7811, Val Accuracy = 0.6920
# Iteration 190: Train Cost = 0.7438, Val Cost = 0.7665, Val Accuracy = 0.7010
# Iteration 200: Train Cost = 0.7308, Val Cost = 0.7534, Val Accuracy = 0.7087
# Iteration 210: Train Cost = 0.7187, Val Cost = 0.7414, Val Accuracy = 0.7164
# Iteration 220: Train Cost = 0.7074, Val Cost = 0.7302, Val Accuracy = 0.7219
# Iteration 230: Train Cost = 0.6967, Val Cost = 0.7196, Val Accuracy = 0.7293
# Iteration 240: Train Cost = 0.6866, Val Cost = 0.7096, Val Accuracy = 0.7347
# Iteration 250: Train Cost = 0.6770, Val Cost = 0.7001, Val Accuracy = 0.7400
# Iteration 260: Train Cost = 0.6679, Val Cost = 0.6911, Val Accuracy = 0.7446
# Iteration 270: Train Cost = 0.6592, Val Cost = 0.6826, Val Accuracy = 0.7482
# Iteration 280: Train Cost = 0.6509, Val Cost = 0.6745, Val Accuracy = 0.7531
# Iteration 290: Train Cost = 0.6431, Val Cost = 0.6669, Val Accuracy = 0.7558
# Iteration 300: Train Cost = 0.6357, Val Cost = 0.6595, Val Accuracy = 0.7593
# Iteration 310: Train Cost = 0.6285, Val Cost = 0.6525, Val Accuracy = 0.7632
# Iteration 320: Train Cost = 0.6216, Val Cost = 0.6458, Val Accuracy = 0.7658
# Iteration 330: Train Cost = 0.6151, Val Cost = 0.6394, Val Accuracy = 0.7688
# Iteration 340: Train Cost = 0.6088, Val Cost = 0.6332, Val Accuracy = 0.7718
# Iteration 350: Train Cost = 0.6028, Val Cost = 0.6273, Val Accuracy = 0.7736
# Iteration 360: Train Cost = 0.5970, Val Cost = 0.6217, Val Accuracy = 0.7750
# Iteration 370: Train Cost = 0.5915, Val Cost = 0.6163, Val Accuracy = 0.7782
# Iteration 380: Train Cost = 0.5862, Val Cost = 0.6110, Val Accuracy = 0.7803
# Iteration 390: Train Cost = 0.5811, Val Cost = 0.6060, Val Accuracy = 0.7830
# Iteration 400: Train Cost = 0.5762, Val Cost = 0.6012, Val Accuracy = 0.7842
# Iteration 410: Train Cost = 0.5716, Val Cost = 0.5964, Val Accuracy = 0.7869
# Iteration 420: Train Cost = 0.5672, Val Cost = 0.5919, Val Accuracy = 0.7881
# Iteration 430: Train Cost = 0.5633, Val Cost = 0.5874, Val Accuracy = 0.7913
# Iteration 440: Train Cost = 0.5602, Val Cost = 0.5829, Val Accuracy = 0.7922
# Iteration 450: Train Cost = 0.5592, Val Cost = 0.5794, Val Accuracy = 0.7951
# Iteration 460: Train Cost = 0.5581, Val Cost = 0.5783, Val Accuracy = 0.7974
# Iteration 470: Train Cost = 0.5507, Val Cost = 0.5751, Val Accuracy = 0.7982
# Iteration 480: Train Cost = 0.5438, Val Cost = 0.5711, Val Accuracy = 0.8001
# Iteration 490: Train Cost = 0.5391, Val Cost = 0.5681, Val Accuracy = 0.8002
# Iteration 499: Train Cost = 0.5420, Val Cost = 0.5636, Val Accuracy = 0.8004
# Accuracy: 0.8004
# Testing with learning rate: 0.1, hidden layer size: 150, lambda: 0.001
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.2975, Val Accuracy = 0.2480
# Iteration 10: Train Cost = 2.2451, Val Cost = 2.2353, Val Accuracy = 0.3193
# Iteration 20: Train Cost = 2.0738, Val Cost = 2.0481, Val Accuracy = 0.4090
# Iteration 30: Train Cost = 1.7629, Val Cost = 1.7337, Val Accuracy = 0.4881
# Iteration 40: Train Cost = 1.4867, Val Cost = 1.4680, Val Accuracy = 0.5682
# Iteration 50: Train Cost = 1.2921, Val Cost = 1.2819, Val Accuracy = 0.6007
# Iteration 60: Train Cost = 1.1539, Val Cost = 1.1500, Val Accuracy = 0.6215
# Iteration 70: Train Cost = 1.0540, Val Cost = 1.0547, Val Accuracy = 0.6360
# Iteration 80: Train Cost = 0.9802, Val Cost = 0.9844, Val Accuracy = 0.6480
# Iteration 90: Train Cost = 0.9244, Val Cost = 0.9314, Val Accuracy = 0.6570
# Iteration 100: Train Cost = 0.8811, Val Cost = 0.8903, Val Accuracy = 0.6656
# Iteration 110: Train Cost = 0.8468, Val Cost = 0.8576, Val Accuracy = 0.6723
# Iteration 120: Train Cost = 0.8188, Val Cost = 0.8310, Val Accuracy = 0.6828
# Iteration 130: Train Cost = 0.7978, Val Cost = 0.8136, Val Accuracy = 0.6924
# Iteration 140: Train Cost = 0.8506, Val Cost = 0.8420, Val Accuracy = 0.6680
# Iteration 150: Train Cost = 0.8117, Val Cost = 0.8131, Val Accuracy = 0.6850
# Iteration 160: Train Cost = 0.7855, Val Cost = 0.7917, Val Accuracy = 0.6979
# Iteration 170: Train Cost = 0.7656, Val Cost = 0.7744, Val Accuracy = 0.7093
# Iteration 180: Train Cost = 0.7491, Val Cost = 0.7595, Val Accuracy = 0.7193
# Iteration 190: Train Cost = 0.7347, Val Cost = 0.7463, Val Accuracy = 0.7266
# Iteration 200: Train Cost = 0.7216, Val Cost = 0.7341, Val Accuracy = 0.7320
# Iteration 210: Train Cost = 0.7095, Val Cost = 0.7228, Val Accuracy = 0.7373
# Iteration 220: Train Cost = 0.6982, Val Cost = 0.7121, Val Accuracy = 0.7440
# Iteration 230: Train Cost = 0.6876, Val Cost = 0.7021, Val Accuracy = 0.7492
# Iteration 240: Train Cost = 0.6775, Val Cost = 0.6927, Val Accuracy = 0.7542
# Iteration 250: Train Cost = 0.6680, Val Cost = 0.6837, Val Accuracy = 0.7576
# Iteration 260: Train Cost = 0.6590, Val Cost = 0.6753, Val Accuracy = 0.7605
# Iteration 270: Train Cost = 0.6504, Val Cost = 0.6672, Val Accuracy = 0.7625
# Iteration 280: Train Cost = 0.6422, Val Cost = 0.6596, Val Accuracy = 0.7643
# Iteration 290: Train Cost = 0.6344, Val Cost = 0.6524, Val Accuracy = 0.7671
# Iteration 300: Train Cost = 0.6269, Val Cost = 0.6454, Val Accuracy = 0.7696
# Iteration 310: Train Cost = 0.6198, Val Cost = 0.6389, Val Accuracy = 0.7709
# Iteration 320: Train Cost = 0.6130, Val Cost = 0.6326, Val Accuracy = 0.7737
# Iteration 330: Train Cost = 0.6065, Val Cost = 0.6266, Val Accuracy = 0.7759
# Iteration 340: Train Cost = 0.6003, Val Cost = 0.6210, Val Accuracy = 0.7782
# Iteration 350: Train Cost = 0.5943, Val Cost = 0.6156, Val Accuracy = 0.7805
# Iteration 360: Train Cost = 0.5885, Val Cost = 0.6105, Val Accuracy = 0.7824
# Iteration 370: Train Cost = 0.5830, Val Cost = 0.6059, Val Accuracy = 0.7837
# Iteration 380: Train Cost = 0.5777, Val Cost = 0.6017, Val Accuracy = 0.7845
# Iteration 390: Train Cost = 0.5725, Val Cost = 0.5985, Val Accuracy = 0.7887
# Iteration 400: Train Cost = 0.5680, Val Cost = 0.5972, Val Accuracy = 0.7918
# Iteration 410: Train Cost = 0.5656, Val Cost = 0.5958, Val Accuracy = 0.7897
# Iteration 420: Train Cost = 0.5625, Val Cost = 0.5890, Val Accuracy = 0.7916
# Iteration 430: Train Cost = 0.5579, Val Cost = 0.5818, Val Accuracy = 0.7955
# Iteration 440: Train Cost = 0.5540, Val Cost = 0.5765, Val Accuracy = 0.7974
# Iteration 450: Train Cost = 0.5508, Val Cost = 0.5723, Val Accuracy = 0.7992
# Iteration 460: Train Cost = 0.5478, Val Cost = 0.5689, Val Accuracy = 0.7981
# Iteration 470: Train Cost = 0.5449, Val Cost = 0.5661, Val Accuracy = 0.7980
# Iteration 480: Train Cost = 0.5422, Val Cost = 0.5644, Val Accuracy = 0.7979
# Iteration 490: Train Cost = 0.5401, Val Cost = 0.5648, Val Accuracy = 0.7976
# Iteration 499: Train Cost = 0.5378, Val Cost = 0.5637, Val Accuracy = 0.8005
# Accuracy: 0.8005
# Testing with learning rate: 0.1, hidden layer size: 150, lambda: 0.01
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.2975, Val Accuracy = 0.2480
# Iteration 10: Train Cost = 2.2451, Val Cost = 2.2353, Val Accuracy = 0.3193
# Iteration 20: Train Cost = 2.0738, Val Cost = 2.0481, Val Accuracy = 0.4090
# Iteration 30: Train Cost = 1.7629, Val Cost = 1.7337, Val Accuracy = 0.4882
# Iteration 40: Train Cost = 1.4867, Val Cost = 1.4680, Val Accuracy = 0.5682
# Iteration 50: Train Cost = 1.2921, Val Cost = 1.2819, Val Accuracy = 0.6007
# Iteration 60: Train Cost = 1.1539, Val Cost = 1.1500, Val Accuracy = 0.6215
# Iteration 70: Train Cost = 1.0540, Val Cost = 1.0547, Val Accuracy = 0.6360
# Iteration 80: Train Cost = 0.9802, Val Cost = 0.9844, Val Accuracy = 0.6480
# Iteration 90: Train Cost = 0.9244, Val Cost = 0.9314, Val Accuracy = 0.6570
# Iteration 100: Train Cost = 0.8811, Val Cost = 0.8903, Val Accuracy = 0.6656
# Iteration 110: Train Cost = 0.8468, Val Cost = 0.8576, Val Accuracy = 0.6723
# Iteration 120: Train Cost = 0.8188, Val Cost = 0.8310, Val Accuracy = 0.6828
# Iteration 130: Train Cost = 0.7980, Val Cost = 0.8141, Val Accuracy = 0.6921
# Iteration 140: Train Cost = 0.8502, Val Cost = 0.8418, Val Accuracy = 0.6680
# Iteration 150: Train Cost = 0.8115, Val Cost = 0.8130, Val Accuracy = 0.6849
# Iteration 160: Train Cost = 0.7854, Val Cost = 0.7916, Val Accuracy = 0.6979
# Iteration 170: Train Cost = 0.7655, Val Cost = 0.7743, Val Accuracy = 0.7093
# Iteration 180: Train Cost = 0.7491, Val Cost = 0.7595, Val Accuracy = 0.7193
# Iteration 190: Train Cost = 0.7347, Val Cost = 0.7463, Val Accuracy = 0.7266
# Iteration 200: Train Cost = 0.7216, Val Cost = 0.7341, Val Accuracy = 0.7320
# Iteration 210: Train Cost = 0.7095, Val Cost = 0.7228, Val Accuracy = 0.7373
# Iteration 220: Train Cost = 0.6982, Val Cost = 0.7121, Val Accuracy = 0.7440
# Iteration 230: Train Cost = 0.6876, Val Cost = 0.7021, Val Accuracy = 0.7492
# Iteration 240: Train Cost = 0.6775, Val Cost = 0.6927, Val Accuracy = 0.7542
# Iteration 250: Train Cost = 0.6680, Val Cost = 0.6837, Val Accuracy = 0.7576
# Iteration 260: Train Cost = 0.6590, Val Cost = 0.6753, Val Accuracy = 0.7605
# Iteration 270: Train Cost = 0.6504, Val Cost = 0.6673, Val Accuracy = 0.7625
# Iteration 280: Train Cost = 0.6422, Val Cost = 0.6596, Val Accuracy = 0.7643
# Iteration 290: Train Cost = 0.6344, Val Cost = 0.6524, Val Accuracy = 0.7671
# Iteration 300: Train Cost = 0.6269, Val Cost = 0.6454, Val Accuracy = 0.7696
# Iteration 310: Train Cost = 0.6198, Val Cost = 0.6389, Val Accuracy = 0.7709
# Iteration 320: Train Cost = 0.6130, Val Cost = 0.6326, Val Accuracy = 0.7737
# Iteration 330: Train Cost = 0.6065, Val Cost = 0.6266, Val Accuracy = 0.7759
# Iteration 340: Train Cost = 0.6003, Val Cost = 0.6210, Val Accuracy = 0.7782
# Iteration 350: Train Cost = 0.5943, Val Cost = 0.6156, Val Accuracy = 0.7805
# Iteration 360: Train Cost = 0.5885, Val Cost = 0.6105, Val Accuracy = 0.7824
# Iteration 370: Train Cost = 0.5830, Val Cost = 0.6059, Val Accuracy = 0.7837
# Iteration 380: Train Cost = 0.5777, Val Cost = 0.6017, Val Accuracy = 0.7845
# Iteration 390: Train Cost = 0.5725, Val Cost = 0.5985, Val Accuracy = 0.7887
# Iteration 400: Train Cost = 0.5680, Val Cost = 0.5972, Val Accuracy = 0.7918
# Iteration 410: Train Cost = 0.5656, Val Cost = 0.5958, Val Accuracy = 0.7896
# Iteration 420: Train Cost = 0.5625, Val Cost = 0.5890, Val Accuracy = 0.7917
# Iteration 430: Train Cost = 0.5579, Val Cost = 0.5818, Val Accuracy = 0.7955
# Iteration 440: Train Cost = 0.5541, Val Cost = 0.5765, Val Accuracy = 0.7974
# Iteration 450: Train Cost = 0.5508, Val Cost = 0.5723, Val Accuracy = 0.7992
# Iteration 460: Train Cost = 0.5478, Val Cost = 0.5689, Val Accuracy = 0.7981
# Iteration 470: Train Cost = 0.5449, Val Cost = 0.5661, Val Accuracy = 0.7980
# Iteration 480: Train Cost = 0.5422, Val Cost = 0.5645, Val Accuracy = 0.7978
# Iteration 490: Train Cost = 0.5401, Val Cost = 0.5648, Val Accuracy = 0.7976
# Iteration 499: Train Cost = 0.5378, Val Cost = 0.5637, Val Accuracy = 0.8005
# Accuracy: 0.8005
# Testing with learning rate: 0.1, hidden layer size: 150, lambda: 0.1
# Iteration 0: Train Cost = 2.3015, Val Cost = 2.2975, Val Accuracy = 0.2480
# Iteration 10: Train Cost = 2.2451, Val Cost = 2.2353, Val Accuracy = 0.3193
# Iteration 20: Train Cost = 2.0738, Val Cost = 2.0482, Val Accuracy = 0.4090
# Iteration 30: Train Cost = 1.7629, Val Cost = 1.7338, Val Accuracy = 0.4881
# Iteration 40: Train Cost = 1.4867, Val Cost = 1.4681, Val Accuracy = 0.5682
# Iteration 50: Train Cost = 1.2921, Val Cost = 1.2820, Val Accuracy = 0.6007
# Iteration 60: Train Cost = 1.1539, Val Cost = 1.1500, Val Accuracy = 0.6215
# Iteration 70: Train Cost = 1.0540, Val Cost = 1.0547, Val Accuracy = 0.6360
# Iteration 80: Train Cost = 0.9802, Val Cost = 0.9845, Val Accuracy = 0.6480
# Iteration 90: Train Cost = 0.9244, Val Cost = 0.9315, Val Accuracy = 0.6570
# Iteration 100: Train Cost = 0.8812, Val Cost = 0.8904, Val Accuracy = 0.6656
# Iteration 110: Train Cost = 0.8468, Val Cost = 0.8577, Val Accuracy = 0.6723
# Iteration 120: Train Cost = 0.8188, Val Cost = 0.8311, Val Accuracy = 0.6828
# Iteration 130: Train Cost = 0.7982, Val Cost = 0.8145, Val Accuracy = 0.6920
# Iteration 140: Train Cost = 0.8499, Val Cost = 0.8417, Val Accuracy = 0.6680
# Iteration 150: Train Cost = 0.8114, Val Cost = 0.8130, Val Accuracy = 0.6849
# Iteration 160: Train Cost = 0.7853, Val Cost = 0.7917, Val Accuracy = 0.6980
# Iteration 170: Train Cost = 0.7655, Val Cost = 0.7744, Val Accuracy = 0.7095
# Iteration 180: Train Cost = 0.7491, Val Cost = 0.7596, Val Accuracy = 0.7193
# Iteration 190: Train Cost = 0.7347, Val Cost = 0.7464, Val Accuracy = 0.7266
# Iteration 200: Train Cost = 0.7217, Val Cost = 0.7342, Val Accuracy = 0.7320
# Iteration 210: Train Cost = 0.7095, Val Cost = 0.7229, Val Accuracy = 0.7373
# Iteration 220: Train Cost = 0.6982, Val Cost = 0.7122, Val Accuracy = 0.7440
# Iteration 230: Train Cost = 0.6876, Val Cost = 0.7022, Val Accuracy = 0.7492
# Iteration 240: Train Cost = 0.6775, Val Cost = 0.6928, Val Accuracy = 0.7542
# Iteration 250: Train Cost = 0.6680, Val Cost = 0.6838, Val Accuracy = 0.7576
# Iteration 260: Train Cost = 0.6590, Val Cost = 0.6754, Val Accuracy = 0.7605
# Iteration 270: Train Cost = 0.6504, Val Cost = 0.6674, Val Accuracy = 0.7625
# Iteration 280: Train Cost = 0.6422, Val Cost = 0.6597, Val Accuracy = 0.7643
# Iteration 290: Train Cost = 0.6344, Val Cost = 0.6525, Val Accuracy = 0.7671
# Iteration 300: Train Cost = 0.6270, Val Cost = 0.6456, Val Accuracy = 0.7696
# Iteration 310: Train Cost = 0.6198, Val Cost = 0.6390, Val Accuracy = 0.7709
# Iteration 320: Train Cost = 0.6130, Val Cost = 0.6327, Val Accuracy = 0.7737
# Iteration 330: Train Cost = 0.6065, Val Cost = 0.6267, Val Accuracy = 0.7759
# Iteration 340: Train Cost = 0.6003, Val Cost = 0.6211, Val Accuracy = 0.7782
# Iteration 350: Train Cost = 0.5943, Val Cost = 0.6157, Val Accuracy = 0.7805
# Iteration 360: Train Cost = 0.5886, Val Cost = 0.6107, Val Accuracy = 0.7824
# Iteration 370: Train Cost = 0.5830, Val Cost = 0.6060, Val Accuracy = 0.7837
# Iteration 380: Train Cost = 0.5777, Val Cost = 0.6018, Val Accuracy = 0.7845
# Iteration 390: Train Cost = 0.5725, Val Cost = 0.5986, Val Accuracy = 0.7887
# Iteration 400: Train Cost = 0.5681, Val Cost = 0.5974, Val Accuracy = 0.7918
# Iteration 410: Train Cost = 0.5657, Val Cost = 0.5959, Val Accuracy = 0.7896
# Iteration 420: Train Cost = 0.5625, Val Cost = 0.5891, Val Accuracy = 0.7918
# Iteration 430: Train Cost = 0.5580, Val Cost = 0.5820, Val Accuracy = 0.7955
# Iteration 440: Train Cost = 0.5541, Val Cost = 0.5766, Val Accuracy = 0.7974
# Iteration 450: Train Cost = 0.5508, Val Cost = 0.5725, Val Accuracy = 0.7992
# Iteration 460: Train Cost = 0.5479, Val Cost = 0.5690, Val Accuracy = 0.7981
# Iteration 470: Train Cost = 0.5449, Val Cost = 0.5662, Val Accuracy = 0.7981
# Iteration 480: Train Cost = 0.5423, Val Cost = 0.5646, Val Accuracy = 0.7978
# Iteration 490: Train Cost = 0.5401, Val Cost = 0.5650, Val Accuracy = 0.7976
# Iteration 499: Train Cost = 0.5378, Val Cost = 0.5639, Val Accuracy = 0.8005
# Accuracy: 0.8005
# Best Parameters: {'lr': 0.1, 'size': 150, 'lambda': 0.001, 'accuracy': 0.8005}

# %%
import pandas as pd

results_df = pd.DataFrame(tuning_results, columns=['Learning Rate', 'Hidden Layer Size', 'Lambda', 'Accuracy'])
results_df.to_csv('hyperparameter_tuning_results.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap of accuracy as a function of learning rate and regularization strength for a fixed hidden layer size
pivot_table = results_df.pivot_table(
    index="Learning Rate", 
    columns="Lambda", 
    values="Accuracy", 
    aggfunc=np.mean  
)

sns.heatmap(pivot_table, annot=True, cmap="coolwarm")
plt.title("Accuracy by Learning Rate and Regularization Strength")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4628\117591612.py:5: FutureWarning: The provided callable <function mean at 0x000001790B5E2200> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = results_df.pivot_table(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap of accuracy as a function of learning rate and hidden layer size
pivot_table = results_df.pivot_table(
    index="Learning Rate", 
    columns="Hidden Layer Size", 
    values="Accuracy", 
    aggfunc=np.mean  
)

sns.heatmap(pivot_table, annot=True, cmap="coolwarm")
plt.title("Accuracy by Learning Rate and Hidden Layer Size")
plt.xlabel("Hidden Layer Size")
plt.ylabel("Learning Rate")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4628\2392557522.py:5: FutureWarning: The provided callable <function mean at 0x000001790B5E2200> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = results_df.pivot_table(

# %%
# Display the top 5 parameter combinations
print(results_df.sort_values(by='Accuracy', ascending=False).head())
# Out:
#     Learning Rate  Hidden Layer Size  Lambda  Accuracy
# 26            0.1                150   0.100    0.8005
# 25            0.1                150   0.010    0.8005
# 24            0.1                150   0.001    0.8005
# 23            0.1                100   0.100    0.8004
# 22            0.1                100   0.010    0.8004

# %% [markdown]
# ### 4. Test and Evaluation

# %%
layer_sizes = [784, 150, 10]  # Use the result from grid research
activations = ['relu', 'softmax']
best_params, train_costs, val_costs, val_accuracies = train_and_evaluate_model(
    X_train, y_train_encoded, X_test, y_test_encoded, layer_sizes, activations,
    learning_rate=0.1, num_iterations=1000, lambd=0.001
)
plot_metrics(train_costs, val_costs, val_accuracies)
# Out:
# Iteration 0: Train Cost = 2.3014, Val Cost = 2.2975, Val Accuracy = 0.2480
# Iteration 10: Train Cost = 2.2451, Val Cost = 2.2353, Val Accuracy = 0.3193
# Iteration 20: Train Cost = 2.0738, Val Cost = 2.0481, Val Accuracy = 0.4090
# Iteration 30: Train Cost = 1.7629, Val Cost = 1.7337, Val Accuracy = 0.4881
# Iteration 40: Train Cost = 1.4867, Val Cost = 1.4680, Val Accuracy = 0.5682
# Iteration 50: Train Cost = 1.2921, Val Cost = 1.2819, Val Accuracy = 0.6007
# Iteration 60: Train Cost = 1.1539, Val Cost = 1.1500, Val Accuracy = 0.6215
# Iteration 70: Train Cost = 1.0540, Val Cost = 1.0547, Val Accuracy = 0.6360
# Iteration 80: Train Cost = 0.9802, Val Cost = 0.9844, Val Accuracy = 0.6480
# Iteration 90: Train Cost = 0.9244, Val Cost = 0.9314, Val Accuracy = 0.6570
# Iteration 100: Train Cost = 0.8811, Val Cost = 0.8903, Val Accuracy = 0.6656
# Iteration 110: Train Cost = 0.8468, Val Cost = 0.8576, Val Accuracy = 0.6723
# Iteration 120: Train Cost = 0.8188, Val Cost = 0.8310, Val Accuracy = 0.6828
# Iteration 130: Train Cost = 0.7978, Val Cost = 0.8136, Val Accuracy = 0.6924
# Iteration 140: Train Cost = 0.8506, Val Cost = 0.8420, Val Accuracy = 0.6680
# Iteration 150: Train Cost = 0.8117, Val Cost = 0.8131, Val Accuracy = 0.6850
# Iteration 160: Train Cost = 0.7855, Val Cost = 0.7917, Val Accuracy = 0.6979
# Iteration 170: Train Cost = 0.7656, Val Cost = 0.7744, Val Accuracy = 0.7093
# Iteration 180: Train Cost = 0.7491, Val Cost = 0.7595, Val Accuracy = 0.7193
# Iteration 190: Train Cost = 0.7347, Val Cost = 0.7463, Val Accuracy = 0.7266
# Iteration 200: Train Cost = 0.7216, Val Cost = 0.7341, Val Accuracy = 0.7320
# Iteration 210: Train Cost = 0.7095, Val Cost = 0.7228, Val Accuracy = 0.7373
# Iteration 220: Train Cost = 0.6982, Val Cost = 0.7121, Val Accuracy = 0.7440
# Iteration 230: Train Cost = 0.6876, Val Cost = 0.7021, Val Accuracy = 0.7492
# Iteration 240: Train Cost = 0.6775, Val Cost = 0.6927, Val Accuracy = 0.7542
# Iteration 250: Train Cost = 0.6680, Val Cost = 0.6837, Val Accuracy = 0.7576
# Iteration 260: Train Cost = 0.6590, Val Cost = 0.6753, Val Accuracy = 0.7605
# Iteration 270: Train Cost = 0.6504, Val Cost = 0.6672, Val Accuracy = 0.7625
# Iteration 280: Train Cost = 0.6422, Val Cost = 0.6596, Val Accuracy = 0.7643
# Iteration 290: Train Cost = 0.6344, Val Cost = 0.6524, Val Accuracy = 0.7671
# Iteration 300: Train Cost = 0.6269, Val Cost = 0.6454, Val Accuracy = 0.7696
# Iteration 310: Train Cost = 0.6198, Val Cost = 0.6389, Val Accuracy = 0.7709
# Iteration 320: Train Cost = 0.6130, Val Cost = 0.6326, Val Accuracy = 0.7737
# Iteration 330: Train Cost = 0.6065, Val Cost = 0.6266, Val Accuracy = 0.7759
# Iteration 340: Train Cost = 0.6003, Val Cost = 0.6210, Val Accuracy = 0.7782
# Iteration 350: Train Cost = 0.5943, Val Cost = 0.6156, Val Accuracy = 0.7805
# Iteration 360: Train Cost = 0.5885, Val Cost = 0.6105, Val Accuracy = 0.7824
# Iteration 370: Train Cost = 0.5830, Val Cost = 0.6059, Val Accuracy = 0.7837
# Iteration 380: Train Cost = 0.5777, Val Cost = 0.6017, Val Accuracy = 0.7845
# Iteration 390: Train Cost = 0.5725, Val Cost = 0.5985, Val Accuracy = 0.7887
# Iteration 400: Train Cost = 0.5680, Val Cost = 0.5972, Val Accuracy = 0.7918
# Iteration 410: Train Cost = 0.5656, Val Cost = 0.5958, Val Accuracy = 0.7897
# Iteration 420: Train Cost = 0.5625, Val Cost = 0.5890, Val Accuracy = 0.7916
# Iteration 430: Train Cost = 0.5579, Val Cost = 0.5818, Val Accuracy = 0.7955
# Iteration 440: Train Cost = 0.5540, Val Cost = 0.5765, Val Accuracy = 0.7974
# Iteration 450: Train Cost = 0.5508, Val Cost = 0.5723, Val Accuracy = 0.7992
# Iteration 460: Train Cost = 0.5478, Val Cost = 0.5689, Val Accuracy = 0.7981
# Iteration 470: Train Cost = 0.5449, Val Cost = 0.5661, Val Accuracy = 0.7980
# Iteration 480: Train Cost = 0.5422, Val Cost = 0.5644, Val Accuracy = 0.7979
# Iteration 490: Train Cost = 0.5401, Val Cost = 0.5648, Val Accuracy = 0.7976
# Iteration 500: Train Cost = 0.5380, Val Cost = 0.5661, Val Accuracy = 0.7972
# Iteration 510: Train Cost = 0.5347, Val Cost = 0.5642, Val Accuracy = 0.7968
# Iteration 520: Train Cost = 0.5324, Val Cost = 0.5597, Val Accuracy = 0.8007
# Iteration 530: Train Cost = 0.5390, Val Cost = 0.5595, Val Accuracy = 0.8002
# Iteration 540: Train Cost = 0.5347, Val Cost = 0.5568, Val Accuracy = 0.8033
# Iteration 550: Train Cost = 0.5230, Val Cost = 0.5490, Val Accuracy = 0.8093
# Iteration 560: Train Cost = 0.5169, Val Cost = 0.5446, Val Accuracy = 0.8110
# Iteration 570: Train Cost = 0.5134, Val Cost = 0.5422, Val Accuracy = 0.8119
# Iteration 580: Train Cost = 0.5107, Val Cost = 0.5402, Val Accuracy = 0.8119
# Iteration 590: Train Cost = 0.5084, Val Cost = 0.5384, Val Accuracy = 0.8119
# Iteration 600: Train Cost = 0.5061, Val Cost = 0.5366, Val Accuracy = 0.8124
# Iteration 610: Train Cost = 0.5040, Val Cost = 0.5349, Val Accuracy = 0.8126
# Iteration 620: Train Cost = 0.5020, Val Cost = 0.5331, Val Accuracy = 0.8128
# Iteration 630: Train Cost = 0.5000, Val Cost = 0.5313, Val Accuracy = 0.8132
# Iteration 640: Train Cost = 0.4980, Val Cost = 0.5296, Val Accuracy = 0.8140
# Iteration 650: Train Cost = 0.4962, Val Cost = 0.5280, Val Accuracy = 0.8146
# Iteration 660: Train Cost = 0.4945, Val Cost = 0.5264, Val Accuracy = 0.8149
# Iteration 670: Train Cost = 0.4928, Val Cost = 0.5248, Val Accuracy = 0.8154
# Iteration 680: Train Cost = 0.4912, Val Cost = 0.5232, Val Accuracy = 0.8155
# Iteration 690: Train Cost = 0.4898, Val Cost = 0.5217, Val Accuracy = 0.8166
# Iteration 700: Train Cost = 0.4885, Val Cost = 0.5202, Val Accuracy = 0.8168
# Iteration 710: Train Cost = 0.4876, Val Cost = 0.5188, Val Accuracy = 0.8170
# Iteration 720: Train Cost = 0.4871, Val Cost = 0.5175, Val Accuracy = 0.8177
# Iteration 730: Train Cost = 0.4870, Val Cost = 0.5163, Val Accuracy = 0.8187
# Iteration 740: Train Cost = 0.4870, Val Cost = 0.5150, Val Accuracy = 0.8187
# Iteration 750: Train Cost = 0.4863, Val Cost = 0.5138, Val Accuracy = 0.8188
# Iteration 760: Train Cost = 0.4849, Val Cost = 0.5131, Val Accuracy = 0.8179
# Iteration 770: Train Cost = 0.4848, Val Cost = 0.5170, Val Accuracy = 0.8143
# Iteration 780: Train Cost = 0.4933, Val Cost = 0.5259, Val Accuracy = 0.8058
# Iteration 790: Train Cost = 0.4883, Val Cost = 0.5166, Val Accuracy = 0.8121
# Iteration 800: Train Cost = 0.4805, Val Cost = 0.5091, Val Accuracy = 0.8154
# Iteration 810: Train Cost = 0.4770, Val Cost = 0.5058, Val Accuracy = 0.8185
# Iteration 820: Train Cost = 0.4757, Val Cost = 0.5045, Val Accuracy = 0.8193
# Iteration 830: Train Cost = 0.4751, Val Cost = 0.5042, Val Accuracy = 0.8195
# Iteration 840: Train Cost = 0.4740, Val Cost = 0.5039, Val Accuracy = 0.8200
# Iteration 850: Train Cost = 0.4724, Val Cost = 0.5031, Val Accuracy = 0.8201
# Iteration 860: Train Cost = 0.4705, Val Cost = 0.5018, Val Accuracy = 0.8216
# Iteration 870: Train Cost = 0.4686, Val Cost = 0.5002, Val Accuracy = 0.8220
# Iteration 880: Train Cost = 0.4669, Val Cost = 0.4986, Val Accuracy = 0.8224
# Iteration 890: Train Cost = 0.4656, Val Cost = 0.4972, Val Accuracy = 0.8219
# Iteration 900: Train Cost = 0.4645, Val Cost = 0.4960, Val Accuracy = 0.8225
# Iteration 910: Train Cost = 0.4636, Val Cost = 0.4949, Val Accuracy = 0.8228
# Iteration 920: Train Cost = 0.4628, Val Cost = 0.4938, Val Accuracy = 0.8225
# Iteration 930: Train Cost = 0.4620, Val Cost = 0.4929, Val Accuracy = 0.8222
# Iteration 940: Train Cost = 0.4611, Val Cost = 0.4921, Val Accuracy = 0.8229
# Iteration 950: Train Cost = 0.4601, Val Cost = 0.4913, Val Accuracy = 0.8232
# Iteration 960: Train Cost = 0.4589, Val Cost = 0.4904, Val Accuracy = 0.8237
# Iteration 970: Train Cost = 0.4576, Val Cost = 0.4893, Val Accuracy = 0.8239
# Iteration 980: Train Cost = 0.4563, Val Cost = 0.4881, Val Accuracy = 0.8241
# Iteration 990: Train Cost = 0.4552, Val Cost = 0.4871, Val Accuracy = 0.8244
# Iteration 999: Train Cost = 0.4516, Val Cost = 0.4874, Val Accuracy = 0.8261

# %%
# Test on the data set
A_test, _ = forward_propagation(X_test, best_params, activations)
test_accuracy = compute_accuracy(A_test, y_test_encoded)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Accuracy: 0.8261
